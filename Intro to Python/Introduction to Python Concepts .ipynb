# %% [markdown]
# ### Python is regarded as the language of Data Science having overtaken R, SAS, Excel

# %% [markdown]
# ## Python Application

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Support for DataScience
# - Python was not built for Data Science but its general-purpose nature and the support of the community in providing third-party tools like Numpy, Pandas, matplotlib, and Scipy has made it the most popular in data science.

# %% [markdown]
# ## Installation
#
# https://www.python.org/downloads/windows/

# %% [markdown]
# ----

# %% [markdown]
# # From Excel to Python
# #### Large volumes of data
#
# - These days we have very large volumes of data at our disposal and we have the opportunity to tap into the data and draw useful conclusions from it. But using Excel for very large datasets is not feasible as Excel can get slower and messier while handling large amounts of data. On the other hand, Python is efficient in handling and cleaning large amounts of data. Therefore, Python is preferred when we have a large amount of data.
#
#
# #### Reproducibility and automation
# - Python code is easier to reproduce. In Data Science, a lot of times, repetitive analysis is required. Repeating tasks in Python is hassle-free. The fact that Excel has a Graphical User Interface makes it more appealing, but that can be a hindrance when you have to repeat the same analysis
#
# #### Advanced custom visualization
# - Making custom visualizations that are easy to read and convey the analysis properly to the audience is a critical task in Data Science. Python is very good at making custom visualizations with its matplotlib package. Excel can not match the level of customization that Python provides.
#
# #### Better at fixing and finding mistakes
# - Mistakes are inevitable in any kind of work specifically in Data Science but Python will make it easier for us to find errors and mistakes. In contrast, tracing your steps in Excel can be difficult and time consuming.

# %% [markdown]
# ---

# %% [markdown]
# # Python Concepts

# %% [markdown]
# ### Syntax of a language
#
# When we speak or write something in English, we follow certain rules and regulations of the English language. In the same way, there are certain rules that we must follow to write programs in a programming language.
#
# The spelling and grammar rules and regulations of a programming language are called syntax.
#
# Python has a very simple syntax that is human-readable which makes it easy for us to make the computer accomplish what we want it to.

# %% [markdown]
# ## Print Statement
#
# - Every language has a different way of displaying or showing things to the user. Python does this with a print statement.

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(23)
# Out:
# 23

# %%
print(2+3)
# Out:
# 5

# %%
print("The Age of the 3 girls is", 2+3, "and the age of the boys is ", 90)
# Out:
# The Age of the 3 girls is 5 and the age of the boys is  90

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  + > Sum
#
#  - > Minus
#
#  * > Multiply
#
#  / > Division

# %%
print(20/2)
# Out:
# 10.0

# %%
print("Multiplication of 7*6 is", 7*6)
# Out:
# Multiplication of 7*6 is 42

# %% [markdown]
# Print the following
# - Add 4 to 5
# - Divide 40 by 2
# - Multiply 7*9

# %% [markdown]
# ### Comments
# - We can add comments that explain things alongside our code so if anyone sees our code later, they know what the code is trying to accomplish. In Python, we can add a comment with the # character. Everything following the # character is treated as a comment instead of code.

# %%
# The code below will display the year
print(2019)
# Out:
# 2019

# %%
# This line will display Hello World
print("Hello World") 

# The code below will display the year
print(2019)
# Out:
# Hello World
# 2019

# %% [markdown]
# ## Variables
# - A variable is a name to which a value can be assigned. It is basically a placeholder to store information. We can store information in a variable and refer to it later by using the variable name. Variables are assigned values using the = operator.

# %%
course=("A variable is a name to which a value can be assigned. It is basically a placeholder to store information. We can store information in a variable and refer to it later by using the variable name. Variables are assigned values using the = operator.")

# %%
print("Data Analysis")
# Out:
# Data Analysis

# %%
courses = ['Data Analysis', 'Data Science', 'BI']

# %%
Joan=("Ngugi")

# %%
Joan
# Out:
# 'Ngugi'

# %%
print(courses)
# Out:
# ['Data Analysis', 'Data Science', 'BI']

# %%
courses[0]
# Out:
# 'Data Analysis'

# %%
courses[2]
# Out:
# 'BI'

# %%
courses[-1]
# Out:
# 'BI'

# %%
courses[-2]
# Out:
# 'Data Science'

# %%
#storing a variable as an integer
salary=20000

# %%
print(salary)
# Out:
# 20000

# %%
# storing a variable as string
x = 'Data Science session'
print(x)
# Out:
#  Data Science session

# %% [markdown]
# ## Work
# - Create a variable called counties
# - List 5 counties as a list[]
# - Print the output
# - Using indexing retrieve the second county
# - Using negative indexing retrieve the third county

# %%
counties=["Nrb","Msa","Ksm","Meru","Nakuru"]
print(counties)
# Out:
# ['Nrb', 'Msa', 'Ksm', 'Meru', 'Nakuru']

# %%
# retrieve the second county
counties[1]
# Out:
# 'Msa'

# %%
# use negative indexing retrieve the third county
counties[-3]
# Out:
# 'Ksm'

# %% [markdown]
# ---

# %% [markdown]
# ## Data Types
# We can have information or data in different forms. For instance, we have numbers, alphabets, alphanumeric values, etc. Therefore, we also have data types in Python. The data type of an item defines the type and range of values that an item can have. There are three main data types:
#
# Numbers
#
# Strings
#
# Booleans

# %%
a=45.33

# %%
print(a)
# Out:
# 45

# %%
type(a)
# Out:
# int

# %%
b=33.33
print(b)
# Out:
# 33.33

# %%
# method/ function ()

# %%
type(b)
# Out:
# float

# %%
print(a+b)
# Out:
# 78.66

# %%
## Numbers

a = 45 # a is an integer variable
b = -34 # b is an integer variable
c = 33.33 # c is a float variable
d = -45.23 # d is a float variable

print(a)
print(b)
print(c)
print(d)

# %%
name='Joan'
type(name)
# Out:
# str

# %%
type(d)

# %%
x = True

# %%
type(x)
# Out:
# bool

# %%
y = False 
type(y)
# Out:
# bool

# %% [markdown]
# ## Strings
# A string is a collection of characters inside single or double quotation marks. In the previous lesson, when we printed Hello World we printed a string.

# %%
message = 'Hello World'
print(message)

message_2 = "Jan-1"
print(message_2)

message_3 = ""
print(message_3)

message_4 = "A"
print(message_4)
# Out:
# Hello World
# Jan-1
#
# A

# %%
message_3 = ""
print(message_3)

# %%
courses = ('Data,Engineer', 'BI')

print(courses)

# %%
x=10
