# %% [markdown]
# ## What is Pandas?
# - Pandas is a very popular Python library that is used for data analysis, which is the second step of the Data Science lifecycle.
# - It offers functionalities to handle and manipulate data very efficiently. It has been widely adopted by people who are not computer scientists or programmers as it makes them move beyond Excel for analyzing data.

# %% [markdown]
# ## Topics
# - Loading CSV, Excel files to juptyer notebook
# - Creating dataframes
# - Read, View and Extract Information
# - Retrieving Basic dataframe information like the descriptive statistics
# - Dealing with missing values
# - Indexing and selecting data from data frames
# - Filtering dataframes
# - Grouping and aggregating dataframes
# - Sorting Dataframes
# - Updating rows and columns in Pandas
# - String Manipulation in Pandas
# - Handling Dates and Timestamps in Pandas.
# - Merging DataFrames

# %% [markdown]
# ### Importing files
#
# - These days almost all of the data that is acquired by companies is entered in spreadsheets using different software such as Excel. The data is in the form of tables. This data is stored in CSV (Comma Separated Values) files that have “.csv” at the end of their name or .xlxs.

# %%
# installing Pandas

#!pip install Pandas
# Out:
# Requirement already satisfied: Pandas in c:\users\jnngugi\appdata\local\programs\python\python37\lib\site-packages (1.1.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jnngugi\appdata\local\programs\python\python37\lib\site-packages (from Pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\jnngugi\appdata\local\programs\python\python37\lib\site-packages (from Pandas) (1.21.5)
# You are using pip version 18.1, however version 21.3.1 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.
# Requirement already satisfied: pytz>=2017.2 in c:\users\jnngugi\appdata\local\programs\python\python37\lib\site-packages (from Pandas) (2020.4)
# Requirement already satisfied: six>=1.5 in c:\users\jnngugi\appdata\local\programs\python\python37\lib\site-packages (from python-dateutil>=2.7.3->Pandas) (1.15.0)

# %% [markdown]
# # 1. Importing Libraries

# %%
## Importing Pandas
import pandas as pd

# %% [markdown]
# ## Pandas DataFrame
# We store tabular data in something called a dataframe. DataFrame is one of the main pandas Data Structures along with Series. It resembles a table with columns and rows.
#
# A dataframe can be created in a number of ways. In this session, we will go through two main ways.
# -  Manually from a dictionary
# - By importing data from an external file, typically a CSV(Comma Separated Values) file. Note that other file formats like Excel, JSON etc can also be imported. However, for this introductory class we will use CSV files.

# %%
## Create a DataFrame from a Dictionary
Products_dict = {
    "product_id" : [1,2,3,4],
    "Product" : ['Geisha','Sunlight','Dove','LifeBuoy'],
    "Rating" : [4,3,5,3]
}
Products_dict
# Out:
# {'product_id': [1, 2, 3, 4],
#  'Product': ['Geisha', 'Sunlight', 'Dove', 'LifeBuoy'],
#  'Rating': [4, 3, 5, 3]}

# %%
type(Products_dict)
# Out:
# dict

# %%
## Accessing values in dictionaries
Products_dict["Rating"]
# Out:
# [4, 3, 5, 3]

# %%
soap_dataframe=pd.DataFrame(Products_dict)
soap_dataframe
# Out:
#    product_id   Product  Rating
# 0           1    Geisha       4
# 1           2  Sunlight       3
# 2           3      Dove       5
# 3           4  LifeBuoy       3

# %%
type(soap_dataframe)

# %%
#Now Lets access Product from the dataframe
soap_dataframe['Product']

# %% [markdown]
# # Customer Churn Data Exploration  using Pandas

# %% [markdown]
# ### Data Source
# - https://community.ibm.com/accelerators/catalog/content/Customer-churn

# %% [markdown]
# ## About our Data[From the IBM SITE]
#
# - This sample data tracks a fictional telco company's customer churn based on a variety of possible factors. The churn column indicates whether or not the customer left within the last month. Other columns include dependents, monthly charges, and information about the types of services each customer has.

# %% [markdown]
# ---

# %% [markdown]
# ## Business Objective/Problem
# ### To analyse all relevant customer data and develop focused customer retention plans.

# %% [markdown]
# ---

# %% [markdown]
# ## Loading files in pandas
# -  Pandas has other inbuilt functions for reading from CSV ,Excel sheets, SQL databases, HTML documents etc.

# %% [markdown]
# ## Loading excel files
#
# #### read_excel() is a pandas method that allows us to access an Excel sheet using Python. The read_excel() method can load the Excel file from the local system or specified URL and the read_excel() method allows us to access Excel files with extension xls, xlsx, xlsm, xlsb, odf, ods and odt.
# ### More info - https://pythonbasics.org/read-excel/

# %% [markdown]
# ## 2. Loading CSV files

# %% [markdown]
# - To import data from a csv file and save it as a dataframe, we will use the pandas inbuilt read_csv() function

# %%
import pandas as pd

# %%
df=pd.read_csv("CustomerChurn.csv")

# %% [markdown]
# - One of the first things a data scientist or data analyst does after reading the data into a dataframe is to get understand your data, first at high level.
# - To do this, one of the first things you do is to analyze a few rows. We use the .head() method

# %%
df.head(2)
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1               Yes           No           No               No
#
#          Contract Paperless Billing    Payment Method Monthly Charges  \
# 0  Month-to-month               Yes  Electronic check           29.85
# 1        One year                No      Mailed check           56.95
#
#    Total Charges Churn
# 0          29.85    No
# 1         1889.5    No
#
# [2 rows x 21 columns]

# %%
df.tail(2)
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service Multiple Lines Internet Service Online Security  ...  \
# 7041           Yes            Yes      Fiber optic              No  ...
# 7042           Yes             No      Fiber optic             Yes  ...
#
#      Device Protection Tech Support Streaming TV Streaming Movies  \
# 7041                No           No           No               No
# 7042               Yes          Yes          Yes              Yes
#
#             Contract Paperless Billing             Payment Method  \
# 7041  Month-to-month               Yes               Mailed check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#      Monthly Charges  Total Charges Churn
# 7041           74.40          306.6   Yes
# 7042          105.65         6844.5    No
#
# [2 rows x 21 columns]

# %%
df.shape
# Out:
# (7043, 21)

# %%
# We can also get the last rows using tail() method.
df.tail()
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 7038           Yes               Yes              DSL             Yes  ...
# 7039           Yes               Yes      Fiber optic              No  ...
# 7040            No  No phone service              DSL             Yes  ...
# 7041           Yes               Yes      Fiber optic              No  ...
# 7042           Yes                No      Fiber optic             Yes  ...
#
#      Device Protection Tech Support Streaming TV Streaming Movies  \
# 7038               Yes          Yes          Yes              Yes
# 7039               Yes           No          Yes              Yes
# 7040                No           No           No               No
# 7041                No           No           No               No
# 7042               Yes          Yes          Yes              Yes
#
#             Contract Paperless Billing             Payment Method  \
# 7038        One year               Yes               Mailed check
# 7039        One year               Yes    Credit card (automatic)
# 7040  Month-to-month               Yes           Electronic check
# 7041  Month-to-month               Yes               Mailed check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#      Monthly Charges  Total Charges Churn
# 7038           84.80         1990.5    No
# 7039          103.20         7362.9    No
# 7040           29.60         346.45    No
# 7041           74.40          306.6   Yes
# 7042          105.65         6844.5    No
#
# [5 rows x 21 columns]

# %%
# We can also specify the number of rows to be printed inside the tail and head methods
df.head(2)
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1               Yes           No           No               No
#
#          Contract Paperless Billing    Payment Method Monthly Charges  \
# 0  Month-to-month               Yes  Electronic check           29.85
# 1        One year                No      Mailed check           56.95
#
#    Total Charges Churn
# 0          29.85    No
# 1         1889.5    No
#
# [2 rows x 21 columns]

# %%
# We can also specify the number of rows to be printed inside the tail and head methods
df.tail(3)
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 7040            No  No phone service              DSL             Yes  ...
# 7041           Yes               Yes      Fiber optic              No  ...
# 7042           Yes                No      Fiber optic             Yes  ...
#
#      Device Protection Tech Support Streaming TV Streaming Movies  \
# 7040                No           No           No               No
# 7041                No           No           No               No
# 7042               Yes          Yes          Yes              Yes
#
#             Contract Paperless Billing             Payment Method  \
# 7040  Month-to-month               Yes           Electronic check
# 7041  Month-to-month               Yes               Mailed check
# 7042        Two year               Yes  Bank transfer (automatic)
#
#      Monthly Charges  Total Charges Churn
# 7040           29.60         346.45    No
# 7041           74.40          306.6   Yes
# 7042          105.65         6844.5    No
#
# [3 rows x 21 columns]

# %% [markdown]
# After viewing the data at high level, we can proceed to get more information about our data.
#
# We will achieve this using the info() method.
#
# info() method will print information about a DataFrame including the number of rows and columns, the datatypes and non-null values as well as the memory usage
#
# The data types are objects, integers, floats datetime.
#
# Object == string
#
# int64 == int
#
# float64 == float
#
# datetime64= date and time

# %%
## use the info method
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LoyaltyID          7043 non-null   int64
#  1   Customer ID        7043 non-null   object
#  2   Senior Citizen     7043 non-null   object
#  3   Partner            7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   Tenure             7043 non-null   int64
#  6   Phone Service      7043 non-null   object
#  7   Multiple Lines     7043 non-null   object
#  8   Internet Service   7043 non-null   object
#  9   Online Security    7043 non-null   object
#  10  Online Backup      7043 non-null   object
#  11  Device Protection  7043 non-null   object
#  12  Tech Support       7043 non-null   object
#  13  Streaming TV       7043 non-null   object
#  14  Streaming Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
#  16  Paperless Billing  7043 non-null   object
#  17  Payment Method     7043 non-null   object
#  18  Monthly Charges    7043 non-null   float64
#  19  Total Charges      7043 non-null   object
#  20  Churn              7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
## get the rows and columns using the shape attribute
df.shape
# Out:
# (7043, 21)

# %% [markdown]
# As you can see, the dataset has 7043 rows and 21 columns.

# %% [markdown]
# We can also get statistical values such as mean, maximum values,minimum values,percentiles, standard deviation using describe() method,

# %%
df.max()
# Out:
# LoyaltyID                  999912
# Customer ID            9995-HOTOH
# Senior Citizen                Yes
# Partner                       Yes
# Dependents                    Yes
# Tenure                         72
# Phone Service                 Yes
# Multiple Lines                Yes
# Internet Service               No
# Online Security               Yes
# Online Backup                 Yes
# Device Protection             Yes
# Tech Support                  Yes
# Streaming TV                  Yes
# Streaming Movies              Yes
# Contract                 Two year
# Paperless Billing             Yes
# Payment Method       Mailed check
# Monthly Charges            118.75
# Total Charges               999.9
# Churn                         Yes
# dtype: object

# %%
df.min()
# Out:
# LoyaltyID                               100346
# Customer ID                         0002-ORFBO
# Senior Citizen                              No
# Partner                                     No
# Dependents                                  No
# Tenure                                       0
# Phone Service                               No
# Multiple Lines                              No
# Internet Service                           DSL
# Online Security                             No
# Online Backup                               No
# Device Protection                           No
# Tech Support                                No
# Streaming TV                                No
# Streaming Movies                            No
# Contract                        Month-to-month
# Paperless Billing                           No
# Payment Method       Bank transfer (automatic)
# Monthly Charges                          18.25
# Total Charges
# Churn                                       No
# dtype: object

# %%
df['Internet Service'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: Internet Service, dtype: int64

# %%
# numerical data (int/float)
df.describe()
# Out:
#            LoyaltyID       Tenure  Monthly Charges
# count    7043.000000  7043.000000      7043.000000
# mean   550382.651001    32.371149        64.761692
# std    260776.118690    24.559481        30.090047
# min    100346.000000     0.000000        18.250000
# 25%    323604.500000     9.000000        35.500000
# 50%    548704.000000    29.000000        70.350000
# 75%    776869.000000    55.000000        89.850000
# max    999912.000000    72.000000       118.750000

# %% [markdown]
# You can use the describe() method to get get information about non-numeric(objects) attributes of your dataframe.

# %%
df.describe(include=['object'])
# Out:
#        Customer ID Senior Citizen Partner Dependents Phone Service  \
# count         7043           7043    7043       7043          7043
# unique        7043              2       2          2             2
# top     0374-AACSZ             No      No         No           Yes
# freq             1           5901    3641       4933          6361
#
#        Multiple Lines Internet Service Online Security Online Backup  \
# count            7043             7043            7043          7043
# unique              3                3               3             3
# top                No      Fiber optic              No            No
# freq             3390             3096            3498          3088
#
#        Device Protection Tech Support Streaming TV Streaming Movies  \
# count               7043         7043         7043             7043
# unique                 3            3            3                3
# top                   No           No           No               No
# freq                3095         3473         2810             2785
#
#               Contract Paperless Billing    Payment Method Churn
# count             7043              7043              7043  7043
# unique               3                 2                 4     2
# top     Month-to-month               Yes  Electronic check    No
# freq              3875              4171              2365  5174

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %% [markdown]
# One of the things to notice about our dataset is that TotalCharges column has integer values but it doesnt appear when we call the describe method.

# %% [markdown]
# ## Converting datatypes --> to numeric values
# - The best way to convert one or more columns of a DataFrame to numeric values is to use pandas.to_numeric().

# %%
df['Total Charges']
# Out:
# 0         29.85
# 1        1889.5
# 2        108.15
# 3       1840.75
# 4        151.65
#          ...
# 7038     1990.5
# 7039     7362.9
# 7040     346.45
# 7041      306.6
# 7042     6844.5
# Name: Total Charges, Length: 7043, dtype: object

# %%
## convert TotalCharges from string to integer

df['Total Charges']=pd.to_numeric(df['Total Charges'], errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   LoyaltyID          7043 non-null   int64
#  1   Customer ID        7043 non-null   object
#  2   Senior Citizen     7043 non-null   object
#  3   Partner            7043 non-null   object
#  4   Dependents         7043 non-null   object
#  5   Tenure             7043 non-null   int64
#  6   Phone Service      7043 non-null   object
#  7   Multiple Lines     7043 non-null   object
#  8   Internet Service   7043 non-null   object
#  9   Online Security    7043 non-null   object
#  10  Online Backup      7043 non-null   object
#  11  Device Protection  7043 non-null   object
#  12  Tech Support       7043 non-null   object
#  13  Streaming TV       7043 non-null   object
#  14  Streaming Movies   7043 non-null   object
#  15  Contract           7043 non-null   object
#  16  Paperless Billing  7043 non-null   object
#  17  Payment Method     7043 non-null   object
#  18  Monthly Charges    7043 non-null   float64
#  19  Total Charges      7032 non-null   float64
#  20  Churn              7043 non-null   object
# dtypes: float64(2), int64(2), object(17)
# memory usage: 1.1+ MB

# %%
#You can also convert datatypes using .astype() method
# example -->To change to a string .astype(object)

df['Total Charges']=df['Total Charges'].astype(float)

# %%
# Datetime conversion using astype:
#df['Contract'] = df['Contract'].astype('datetime64[ns]')

# %% [markdown]
# Our datasets in some cases will have verbose column names with symbols, upper and lowercase words, spaces, and typos. You can always clean up your columns names, but first you need to view them using the columns attribute

# %%
df.columns
# Out:
# Index(['Senior Citizen', 'Partner', 'Dependents', 'Tenure', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %% [markdown]
# # Renaming Columns
# ## We can change specific column names using the rename function  .rename()

# %%
df.head(2)
# Out:
#   Senior Citizen Partner Dependents  Tenure Phone Service    Multiple Lines  \
# 0             No     Yes         No       1            No  No phone service
# 1             No      No         No      34           Yes                No
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL              No           Yes                No
# 1              DSL             Yes            No               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No        One year
#
#   Paperless Billing    Payment Method  Monthly Charges Total Charges Churn
# 0               Yes  Electronic check            29.85         29.85    No
# 1                No      Mailed check            56.95        1889.5    No

# %%
## find missing rows
df.isnull().sum()
# Out:
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %%
df.drop(["Customer ID","LoyaltyID"], inplace=True, axis=1)

# %%
df.rename(columns=
         {
          'Dependents' : 'Children',
          'Tech Support'  : 'IT Support',
          'Customer ID': 'CustID'
         }
         ,inplace = True
         )

# %% [markdown]
# ## Replacing spaces with underscores

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'CustomerID', 'SeniorCitizen', 'Partner', 'Dependents',
#        'Tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# clear space
df.columns=df.columns.str.replace(' ','')

# %%
# replace space with dash
df.columns=df.columns.str.replace(" "  ,  "_")

# %%
df.head()
# Out:
#    LoyaltyID      CustID Senior_Citizen Partner Children  Tenure  \
# 0     318537  7590-VHVEG             No     Yes       No       1
# 1     152148  5575-GNVDE             No      No       No      34
# 2     326527  3668-QPYBK             No      No       No       2
# 3     845894  7795-CFOCW             No      No       No      45
# 4     503388  9237-HQITU             No      No       No       2
#
#   Phone_Service    Multiple_Lines Internet_Service Online_Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
# 2           Yes                No              DSL             Yes  ...
# 3            No  No phone service              DSL             Yes  ...
# 4           Yes                No      Fiber optic              No  ...
#
#   Device_Protection IT_Support Streaming_TV Streaming_Movies        Contract  \
# 0                No         No           No               No  Month-to-month
# 1               Yes         No           No               No        One year
# 2                No         No           No               No  Month-to-month
# 3               Yes        Yes           No               No        One year
# 4                No         No           No               No  Month-to-month
#
#   Paperless_Billing             Payment_Method Monthly_Charges  Total_Charges  \
# 0               Yes           Electronic check           29.85          29.85
# 1                No               Mailed check           56.95        1889.50
# 2               Yes               Mailed check           53.85         108.15
# 3                No  Bank transfer (automatic)           42.30        1840.75
# 4               Yes           Electronic check           70.70         151.65
#
#    Churn
# 0     No
# 1     No
# 2    Yes
# 3     No
# 4    Yes
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Converting strings to upper or lower cases

# %%
df['Churn']=df['Churn'].str.upper()
df.head()
# Out:
#    LoyaltyID  CustomerID SeniorCitizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG            No     Yes         No       1
# 1     152148  5575-GNVDE            No      No         No      34
# 2     326527  3668-QPYBK            No      No         No       2
# 3     845894  7795-CFOCW            No      No         No      45
# 4     503388  9237-HQITU            No      No         No       2
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
# 3           No  No phone service             DSL            Yes  ...
# 4          Yes                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# 3              Yes         Yes          No              No        One year
# 4               No          No          No              No  Month-to-month
#
#   PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0              Yes           Electronic check          29.85         29.85
# 1               No               Mailed check          56.95        1889.5
# 2              Yes               Mailed check          53.85        108.15
# 3               No  Bank transfer (automatic)          42.30       1840.75
# 4              Yes           Electronic check          70.70        151.65
#
#   Churn
# 0    NO
# 1    NO
# 2   YES
# 3    NO
# 4   YES
#
# [5 rows x 21 columns]

# %%
df['Churn']=df['Churn'].str.upper()
df.head()
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
# 2     326527  3668-QPYBK             No      No         No       2
# 3     845894  7795-CFOCW             No      No         No      45
# 4     503388  9237-HQITU             No      No         No       2
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
# 2           Yes                No              DSL             Yes  ...
# 3            No  No phone service              DSL             Yes  ...
# 4           Yes                No      Fiber optic              No  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1               Yes           No           No               No
# 2                No           No           No               No
# 3               Yes          Yes           No               No
# 4                No           No           No               No
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes           Electronic check
# 1        One year                No               Mailed check
# 2  Month-to-month               Yes               Mailed check
# 3        One year                No  Bank transfer (automatic)
# 4  Month-to-month               Yes           Electronic check
#
#   Monthly Charges  Total Charges Churn
# 0           29.85          29.85    NO
# 1           56.95         1889.5    NO
# 2           53.85         108.15   YES
# 3           42.30        1840.75    NO
# 4           70.70         151.65   YES
#
# [5 rows x 21 columns]

# %% [markdown]
# ## # Indexing and Selection
# - Indexing is the technique of selecting particular rows and columns of data from a DataFrame.
# - This can be done in two ways:
#
# Square Brackets eg in lists, NumPy arrays etc [ ]
#
# Advanced Methods : ie loc and iloc

# %%
x=["Toyota","Volvo","BMW","Subaru"]

# %%
x[1]
# Out:
# 'Volvo'

# %%
type(x)
# Out:
# list

# %% [markdown]
# ## SQUARE BRACKETS [ ]
# COLUMN ACCESS WITH SQUARE BRACKETS

# %% [markdown]
# ## Column Access with Brackets
# We can extract a column by using its label (column name) and the square bracket notation:[Series]

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
df['Multiple Lines']
# Out:
# 0       No phone service
# 1                     No
# 2                     No
# 3       No phone service
# 4                     No
#               ...
# 7038                 Yes
# 7039                 Yes
# 7040    No phone service
# 7041                 Yes
# 7042                  No
# Name: Multiple Lines, Length: 7043, dtype: object

# %%
df[['Multiple Lines']]
# Out:
#         Multiple Lines
# 0     No phone service
# 1                   No
# 2                   No
# 3     No phone service
# 4                   No
# ...                ...
# 7038               Yes
# 7039               Yes
# 7040  No phone service
# 7041               Yes
# 7042                No
#
# [7043 rows x 1 columns]

# %%
df[['Multiple Lines','Churn','Tenure']]
# Out:
#         Multiple Lines Churn  Tenure
# 0     No phone service    NO       1
# 1                   No    NO      34
# 2                   No   YES       2
# 3     No phone service    NO      45
# 4                   No   YES       2
# ...                ...   ...     ...
# 7038               Yes    NO      24
# 7039               Yes    NO      72
# 7040  No phone service    NO      11
# 7041               Yes   YES       4
# 7042                No    NO      66
#
# [7043 rows x 3 columns]

# %% [markdown]
# If we want to obtain a DataFrame object as output instead, then we need to pass the column name(s) as a list (double square brackets)

# %%
CL= df[['Internet Service','Tenure','Churn']]
CL
# Out:
#      Internet Service  Tenure Churn
# 0                 DSL       1    No
# 1                 DSL      34    No
# 2                 DSL       2   Yes
# 3                 DSL      45    No
# 4         Fiber optic       2   Yes
# ...               ...     ...   ...
# 7038              DSL      24    No
# 7039      Fiber optic      72    No
# 7040              DSL      11    No
# 7041      Fiber optic       4   Yes
# 7042      Fiber optic      66    No
#
# [7043 rows x 3 columns]

# %%
type(IS)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Extract Multiple Columns

# %%
# If we want to select more than one column for instance using square brackets then we do as below:
df[['Contract','Payment Method','Monthly Charges']]
# Out:
#             Contract             Payment Method  Monthly Charges
# 0     Month-to-month           Electronic check            29.85
# 1           One year               Mailed check            56.95
# 2     Month-to-month               Mailed check            53.85
# 3           One year  Bank transfer (automatic)            42.30
# 4     Month-to-month           Electronic check            70.70
# ...              ...                        ...              ...
# 7038        One year               Mailed check            84.80
# 7039        One year    Credit card (automatic)           103.20
# 7040  Month-to-month           Electronic check            29.60
# 7041  Month-to-month               Mailed check            74.40
# 7042        Two year  Bank transfer (automatic)           105.65
#
# [7043 rows x 3 columns]

# %% [markdown]
# ## Note
# - For df[[colname(s)]], the interior brackets are for list, and the outside brackets are indexing operator, i.e. you must use double brackets if you select two or more columns.
# - With one column name, single pair of brackets returns a Series, while double brackets return a dataframe.

# %% [markdown]
# ## ROW ACCESS WITH SQUARE BRACKETS

# %%
df.tail(10)
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 7033     477869  9767-FFLEM             No      No         No      38
# 7034     175841  0639-TSIQW             No      No         No      67
# 7035     956970  8456-QDAVC             No      No         No      19
# 7036     210184  7750-EYXWZ             No      No         No      12
# 7037     852094  2569-WGERO             No      No         No      72
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7039     230811  2234-XADUH             No     Yes        Yes      72
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
# 7041     731782  8361-LTMKD            Yes     Yes         No       4
# 7042     353947  3186-AJIEK             No      No         No      66
#
#      Phone Service    Multiple Lines Internet Service      Online Security  \
# 7033           Yes                No      Fiber optic                   No
# 7034           Yes               Yes      Fiber optic                  Yes
# 7035           Yes                No      Fiber optic                   No
# 7036            No  No phone service              DSL                   No
# 7037           Yes                No               No  No internet service
# 7038           Yes               Yes              DSL                  Yes
# 7039           Yes               Yes      Fiber optic                   No
# 7040            No  No phone service              DSL                  Yes
# 7041           Yes               Yes      Fiber optic                   No
# 7042           Yes                No      Fiber optic                  Yes
#
#       ...    Device Protection         Tech Support         Streaming TV  \
# 7033  ...                   No                   No                   No
# 7034  ...                  Yes                   No                  Yes
# 7035  ...                   No                   No                  Yes
# 7036  ...                  Yes                  Yes                  Yes
# 7037  ...  No internet service  No internet service  No internet service
# 7038  ...                  Yes                  Yes                  Yes
# 7039  ...                  Yes                   No                  Yes
# 7040  ...                   No                   No                   No
# 7041  ...                   No                   No                   No
# 7042  ...                  Yes                  Yes                  Yes
#
#          Streaming Movies        Contract Paperless Billing  \
# 7033                   No  Month-to-month               Yes
# 7034                   No  Month-to-month               Yes
# 7035                   No  Month-to-month               Yes
# 7036                  Yes        One year                No
# 7037  No internet service        Two year               Yes
# 7038                  Yes        One year               Yes
# 7039                  Yes        One year               Yes
# 7040                   No  Month-to-month               Yes
# 7041                   No  Month-to-month               Yes
# 7042                  Yes        Two year               Yes
#
#                  Payment Method Monthly Charges  Total Charges Churn
# 7033    Credit card (automatic)           69.50        2625.25    NO
# 7034    Credit card (automatic)          102.95        6886.25   YES
# 7035  Bank transfer (automatic)           78.70         1495.1    NO
# 7036           Electronic check           60.65          743.3    NO
# 7037  Bank transfer (automatic)           21.15         1419.4    NO
# 7038               Mailed check           84.80         1990.5    NO
# 7039    Credit card (automatic)          103.20         7362.9    NO
# 7040           Electronic check           29.60         346.45    NO
# 7041               Mailed check           74.40          306.6   YES
# 7042  Bank transfer (automatic)          105.65         6844.5    NO
#
# [10 rows x 21 columns]

# %%
df.head(10)
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
# 2     326527  3668-QPYBK             No      No         No       2
# 3     845894  7795-CFOCW             No      No         No      45
# 4     503388  9237-HQITU             No      No         No       2
# 5     160192  9305-CDSKC             No      No         No       8
# 6     680623  1452-KIOVK             No      No        Yes      22
# 7     340874  6713-OKOMC             No      No         No      10
# 8     582674  7892-POOKP             No     Yes         No      28
# 9     303784  6388-TABGU             No      No        Yes      62
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
# 2           Yes                No              DSL             Yes  ...
# 3            No  No phone service              DSL             Yes  ...
# 4           Yes                No      Fiber optic              No  ...
# 5           Yes               Yes      Fiber optic              No  ...
# 6           Yes               Yes      Fiber optic              No  ...
# 7            No  No phone service              DSL             Yes  ...
# 8           Yes               Yes      Fiber optic              No  ...
# 9           Yes                No              DSL             Yes  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1               Yes           No           No               No
# 2                No           No           No               No
# 3               Yes          Yes           No               No
# 4                No           No           No               No
# 5               Yes           No          Yes              Yes
# 6                No           No          Yes               No
# 7                No           No           No               No
# 8               Yes          Yes          Yes              Yes
# 9                No           No           No               No
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes           Electronic check
# 1        One year                No               Mailed check
# 2  Month-to-month               Yes               Mailed check
# 3        One year                No  Bank transfer (automatic)
# 4  Month-to-month               Yes           Electronic check
# 5  Month-to-month               Yes           Electronic check
# 6  Month-to-month               Yes    Credit card (automatic)
# 7  Month-to-month                No               Mailed check
# 8  Month-to-month               Yes           Electronic check
# 9        One year                No  Bank transfer (automatic)
#
#   Monthly Charges  Total Charges Churn
# 0           29.85          29.85    NO
# 1           56.95         1889.5    NO
# 2           53.85         108.15   YES
# 3           42.30        1840.75    NO
# 4           70.70         151.65   YES
# 5           99.65          820.5   YES
# 6           89.10         1949.4    NO
# 7           29.75          301.9    NO
# 8          104.80        3046.05   YES
# 9           56.15        3487.95    NO
#
# [10 rows x 21 columns]

# %%
#Suppose we want to get from row 0 to 15 :
df[8:9]
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 8     582674  7892-POOKP             No     Yes         No      28
#
#   Phone Service Multiple Lines Internet Service Online Security  ...  \
# 8           Yes            Yes      Fiber optic              No  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 8               Yes          Yes          Yes              Yes
#
#          Contract Paperless Billing    Payment Method Monthly Charges  \
# 8  Month-to-month               Yes  Electronic check           104.8
#
#    Total Charges Churn
# 8        3046.05   YES
#
# [1 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
#Suppose we want to get from row 0 to 4  and the columns customerid and churn:
df[0:5][["Customer ID","Partner","Churn"]]
# Out:
#   Customer ID Partner Churn
# 0  7590-VHVEG     Yes    No
# 1  5575-GNVDE      No    No
# 2  3668-QPYBK      No   Yes
# 3  7795-CFOCW      No    No
# 4  9237-HQITU      No   Yes

# %% [markdown]
# ## Working With Rows using loc and iloc
#
# - loc: the loc attribute allows indexing and slicing that always references the explicit index
# - iloc: the iloc attribute allows indexing and slicing that always references the implicit Python-style index, i.e., locates by numerical index.

# %%
x=["Monday","Tuesday","Wednesday"]
x[1]
# Out:
# 'Tuesday'

# %%
df.head()
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0     318537  7590-VHVEG             No     Yes         No       1
# 1     152148  5575-GNVDE             No      No         No      34
# 2     326527  3668-QPYBK             No      No         No       2
# 3     845894  7795-CFOCW             No      No         No      45
# 4     503388  9237-HQITU             No      No         No       2
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
# 2           Yes                No              DSL             Yes  ...
# 3            No  No phone service              DSL             Yes  ...
# 4           Yes                No      Fiber optic              No  ...
#
#   Device Protection Tech Support Streaming TV Streaming Movies  \
# 0                No           No           No               No
# 1               Yes           No           No               No
# 2                No           No           No               No
# 3               Yes          Yes           No               No
# 4                No           No           No               No
#
#          Contract Paperless Billing             Payment Method  \
# 0  Month-to-month               Yes           Electronic check
# 1        One year                No               Mailed check
# 2  Month-to-month               Yes               Mailed check
# 3        One year                No  Bank transfer (automatic)
# 4  Month-to-month               Yes           Electronic check
#
#   Monthly Charges  Total Charges Churn
# 0           29.85          29.85    No
# 1           56.95         1889.5    No
# 2           53.85         108.15   Yes
# 3           42.30        1840.75    No
# 4           70.70         151.65   Yes
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Senior Citizen', 'Partner', 'Dependents', 'Tenure',
#        'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %% [markdown]
# SET INDEX

# %%
#Lets set customerid as our index to better explain loc and iloc
df.set_index('Customer ID',inplace = True)
df
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 7590-VHVEG      318537             No     Yes         No       1
# 5575-GNVDE      152148             No      No         No      34
# 3668-QPYBK      326527             No      No         No       2
# 7795-CFOCW      845894             No      No         No      45
# 9237-HQITU      503388             No      No         No       2
# ...                ...            ...     ...        ...     ...
# 6840-RESVB      810338             No     Yes        Yes      24
# 2234-XADUH      230811             No     Yes        Yes      72
# 4801-JZAZL      155157             No     Yes        Yes      11
# 8361-LTMKD      731782            Yes     Yes         No       4
# 3186-AJIEK      353947             No      No         No      66
#
#             Phone Service    Multiple Lines Internet Service Online Security  \
# Customer ID
# 7590-VHVEG             No  No phone service              DSL              No
# 5575-GNVDE            Yes                No              DSL             Yes
# 3668-QPYBK            Yes                No              DSL             Yes
# 7795-CFOCW             No  No phone service              DSL             Yes
# 9237-HQITU            Yes                No      Fiber optic              No
# ...                   ...               ...              ...             ...
# 6840-RESVB            Yes               Yes              DSL             Yes
# 2234-XADUH            Yes               Yes      Fiber optic              No
# 4801-JZAZL             No  No phone service              DSL             Yes
# 8361-LTMKD            Yes               Yes      Fiber optic              No
# 3186-AJIEK            Yes                No      Fiber optic             Yes
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 7590-VHVEG            Yes                No           No           No
# 5575-GNVDE             No               Yes           No           No
# 3668-QPYBK            Yes                No           No           No
# 7795-CFOCW             No               Yes          Yes           No
# 9237-HQITU             No                No           No           No
# ...                   ...               ...          ...          ...
# 6840-RESVB             No               Yes          Yes          Yes
# 2234-XADUH            Yes               Yes           No          Yes
# 4801-JZAZL             No                No           No           No
# 8361-LTMKD             No                No           No           No
# 3186-AJIEK             No               Yes          Yes          Yes
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 7590-VHVEG                No  Month-to-month               Yes
# 5575-GNVDE                No        One year                No
# 3668-QPYBK                No  Month-to-month               Yes
# 7795-CFOCW                No        One year                No
# 9237-HQITU                No  Month-to-month               Yes
# ...                      ...             ...               ...
# 6840-RESVB               Yes        One year               Yes
# 2234-XADUH               Yes        One year               Yes
# 4801-JZAZL                No  Month-to-month               Yes
# 8361-LTMKD                No  Month-to-month               Yes
# 3186-AJIEK               Yes        Two year               Yes
#
#                         Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 7590-VHVEG            Electronic check            29.85         29.85    No
# 5575-GNVDE                Mailed check            56.95        1889.5    No
# 3668-QPYBK                Mailed check            53.85        108.15   Yes
# 7795-CFOCW   Bank transfer (automatic)            42.30       1840.75    No
# 9237-HQITU            Electronic check            70.70        151.65   Yes
# ...                                ...              ...           ...   ...
# 6840-RESVB                Mailed check            84.80        1990.5    No
# 2234-XADUH     Credit card (automatic)           103.20        7362.9    No
# 4801-JZAZL            Electronic check            29.60        346.45    No
# 8361-LTMKD                Mailed check            74.40         306.6   Yes
# 3186-AJIEK   Bank transfer (automatic)           105.65        6844.5    No
#
# [7043 rows x 20 columns]

# %%
df.head()
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 7590-VHVEG      318537             No     Yes         No       1
# 5575-GNVDE      152148             No      No         No      34
# 3668-QPYBK      326527             No      No         No       2
# 7795-CFOCW      845894             No      No         No      45
# 9237-HQITU      503388             No      No         No       2
#
#             Phone Service    Multiple Lines Internet Service Online Security  \
# Customer ID
# 7590-VHVEG             No  No phone service              DSL              No
# 5575-GNVDE            Yes                No              DSL             Yes
# 3668-QPYBK            Yes                No              DSL             Yes
# 7795-CFOCW             No  No phone service              DSL             Yes
# 9237-HQITU            Yes                No      Fiber optic              No
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 7590-VHVEG            Yes                No           No           No
# 5575-GNVDE             No               Yes           No           No
# 3668-QPYBK            Yes                No           No           No
# 7795-CFOCW             No               Yes          Yes           No
# 9237-HQITU             No                No           No           No
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 7590-VHVEG                No  Month-to-month               Yes
# 5575-GNVDE                No        One year                No
# 3668-QPYBK                No  Month-to-month               Yes
# 7795-CFOCW                No        One year                No
# 9237-HQITU                No  Month-to-month               Yes
#
#                         Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 7590-VHVEG            Electronic check            29.85         29.85    No
# 5575-GNVDE                Mailed check            56.95        1889.5    No
# 3668-QPYBK                Mailed check            53.85        108.15   Yes
# 7795-CFOCW   Bank transfer (automatic)            42.30       1840.75    No
# 9237-HQITU            Electronic check            70.70        151.65   Yes

# %% [markdown]
# Accessing a specific row using loc

# %%
df.head(2)
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 7590-VHVEG      318537             No     Yes         No       1
# 5575-GNVDE      152148             No      No         No      34
#
#             Phone Service    Multiple Lines Internet Service Online Security  \
# Customer ID
# 7590-VHVEG             No  No phone service              DSL              No
# 5575-GNVDE            Yes                No              DSL             Yes
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 7590-VHVEG            Yes                No           No           No
# 5575-GNVDE             No               Yes           No           No
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 7590-VHVEG                No  Month-to-month               Yes
# 5575-GNVDE                No        One year                No
#
#                Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 7590-VHVEG   Electronic check            29.85         29.85    No
# 5575-GNVDE       Mailed check            56.95        1889.5    No

# %%
# Accessing a Row using loc
df.loc[["7590-VHVEG","5575-GNVDE"]]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 7590-VHVEG      318537             No     Yes         No       1
# 5575-GNVDE      152148             No      No         No      34
#
#             Phone Service    Multiple Lines Internet Service Online Security  \
# Customer ID
# 7590-VHVEG             No  No phone service              DSL              No
# 5575-GNVDE            Yes                No              DSL             Yes
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 7590-VHVEG            Yes                No           No           No
# 5575-GNVDE             No               Yes           No           No
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 7590-VHVEG                No  Month-to-month               Yes
# 5575-GNVDE                No        One year                No
#
#                Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 7590-VHVEG   Electronic check            29.85         29.85    No
# 5575-GNVDE       Mailed check            56.95        1889.5    No

# %%
df[7000:7043]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 0052-YNYOT      368391             No      No         No      67
# 6304-IJFSQ      729518             No      No         No       3
# 9586-JGQKH      236749             No     Yes         No      64
# 4501-VCPFK      406608             No      No         No      26
# 6075-SLNIL      889198             No      No         No      38
# 9347-AERRL      148453             No     Yes         No      23
# 0093-XWZFY      963028             No      No         No      40
# 2274-XUATA      807666            Yes     Yes         No      72
# 1980-KXVPM      250380            Yes      No         No       3
# 7703-ZEKEF      460336             No      No         No      23
# 0723-DRCLG      806194            Yes     Yes         No       1
# 5482-NUPNA      747956             No      No         No       4
# 6691-CCIHA      964367             No     Yes         No      62
# 1685-BQULA      204111             No      No         No      40
# 9053-EJUNL      243758             No      No         No      41
# 0666-UXTJO      660156            Yes     Yes         No      34
# 1471-GIQKQ      683791             No      No         No       1
# 4807-IZYOZ      465592             No      No         No      51
# 1122-JWTJW      961184             No     Yes        Yes       1
# 9710-NJERN      742167             No      No         No      39
# 9837-FWLCH      216689             No     Yes        Yes      12
# 1699-HPSBG      265508             No      No         No      12
# 7203-OYKCT      482402             No      No         No      72
# 1035-IPQPU      818769            Yes     Yes         No      63
# 7398-LXGYX      358421             No     Yes         No      44
# 2823-LKABH      842064             No      No         No      18
# 8775-CEBBJ      773737             No      No         No       9
# 0550-DCXLH      505036             No      No         No      13
# 9281-CEDRU      893287             No     Yes         No      68
# 2235-DWLJU      695438            Yes      No         No       6
# 0871-OPBXW      747903             No      No         No       2
# 3605-JISKB      847238            Yes     Yes         No      55
# 6894-LFHLY      137858            Yes      No         No       1
# 9767-FFLEM      477869             No      No         No      38
# 0639-TSIQW      175841             No      No         No      67
# 8456-QDAVC      956970             No      No         No      19
# 7750-EYXWZ      210184             No      No         No      12
# 2569-WGERO      852094             No      No         No      72
# 6840-RESVB      810338             No     Yes        Yes      24
# 2234-XADUH      230811             No     Yes        Yes      72
# 4801-JZAZL      155157             No     Yes        Yes      11
# 8361-LTMKD      731782            Yes     Yes         No       4
# 3186-AJIEK      353947             No      No         No      66
#
#             Phone Service    Multiple Lines Internet Service  \
# Customer ID
# 0052-YNYOT            Yes                No               No
# 6304-IJFSQ            Yes                No              DSL
# 9586-JGQKH            Yes               Yes      Fiber optic
# 4501-VCPFK             No  No phone service              DSL
# 6075-SLNIL            Yes               Yes      Fiber optic
# 9347-AERRL            Yes                No               No
# 0093-XWZFY            Yes               Yes      Fiber optic
# 2274-XUATA             No  No phone service              DSL
# 1980-KXVPM            Yes               Yes      Fiber optic
# 7703-ZEKEF            Yes               Yes      Fiber optic
# 0723-DRCLG            Yes               Yes      Fiber optic
# 5482-NUPNA            Yes                No              DSL
# 6691-CCIHA            Yes               Yes              DSL
# 1685-BQULA            Yes               Yes      Fiber optic
# 9053-EJUNL            Yes               Yes      Fiber optic
# 0666-UXTJO            Yes                No      Fiber optic
# 1471-GIQKQ            Yes                No              DSL
# 4807-IZYOZ            Yes                No               No
# 1122-JWTJW            Yes                No      Fiber optic
# 9710-NJERN            Yes                No               No
# 9837-FWLCH            Yes                No               No
# 1699-HPSBG            Yes                No              DSL
# 7203-OYKCT            Yes               Yes      Fiber optic
# 1035-IPQPU            Yes               Yes      Fiber optic
# 7398-LXGYX            Yes               Yes      Fiber optic
# 2823-LKABH            Yes               Yes      Fiber optic
# 8775-CEBBJ            Yes                No              DSL
# 0550-DCXLH            Yes                No              DSL
# 9281-CEDRU            Yes                No              DSL
# 2235-DWLJU             No  No phone service              DSL
# 0871-OPBXW            Yes                No               No
# 3605-JISKB            Yes               Yes              DSL
# 6894-LFHLY            Yes               Yes      Fiber optic
# 9767-FFLEM            Yes                No      Fiber optic
# 0639-TSIQW            Yes               Yes      Fiber optic
# 8456-QDAVC            Yes                No      Fiber optic
# 7750-EYXWZ             No  No phone service              DSL
# 2569-WGERO            Yes                No               No
# 6840-RESVB            Yes               Yes              DSL
# 2234-XADUH            Yes               Yes      Fiber optic
# 4801-JZAZL             No  No phone service              DSL
# 8361-LTMKD            Yes               Yes      Fiber optic
# 3186-AJIEK            Yes                No      Fiber optic
#
#                  Online Security        Online Backup    Device Protection  \
# Customer ID
# 0052-YNYOT   No internet service  No internet service  No internet service
# 6304-IJFSQ                    No                  Yes                   No
# 9586-JGQKH                    No                  Yes                   No
# 4501-VCPFK                    No                   No                  Yes
# 6075-SLNIL                    No                  Yes                  Yes
# 9347-AERRL   No internet service  No internet service  No internet service
# 0093-XWZFY                    No                  Yes                  Yes
# 2274-XUATA                   Yes                  Yes                  Yes
# 1980-KXVPM                    No                   No                   No
# 7703-ZEKEF                    No                   No                  Yes
# 0723-DRCLG                    No                   No                   No
# 5482-NUPNA                   Yes                  Yes                   No
# 6691-CCIHA                   Yes                  Yes                   No
# 1685-BQULA                    No                  Yes                  Yes
# 9053-EJUNL                    No                  Yes                   No
# 0666-UXTJO                    No                   No                  Yes
# 1471-GIQKQ                    No                  Yes                   No
# 4807-IZYOZ   No internet service  No internet service  No internet service
# 1122-JWTJW                    No                   No                   No
# 9710-NJERN   No internet service  No internet service  No internet service
# 9837-FWLCH   No internet service  No internet service  No internet service
# 1699-HPSBG                    No                   No                   No
# 7203-OYKCT                    No                  Yes                  Yes
# 1035-IPQPU                    No                  Yes                  Yes
# 7398-LXGYX                   Yes                   No                  Yes
# 2823-LKABH                    No                   No                  Yes
# 8775-CEBBJ                    No                   No                   No
# 0550-DCXLH                    No                  Yes                   No
# 9281-CEDRU                    No                  Yes                   No
# 2235-DWLJU                    No                   No                   No
# 0871-OPBXW   No internet service  No internet service  No internet service
# 3605-JISKB                   Yes                  Yes                   No
# 6894-LFHLY                    No                   No                   No
# 9767-FFLEM                    No                   No                   No
# 0639-TSIQW                   Yes                  Yes                  Yes
# 8456-QDAVC                    No                   No                   No
# 7750-EYXWZ                    No                  Yes                  Yes
# 2569-WGERO   No internet service  No internet service  No internet service
# 6840-RESVB                   Yes                   No                  Yes
# 2234-XADUH                    No                  Yes                  Yes
# 4801-JZAZL                   Yes                   No                   No
# 8361-LTMKD                    No                   No                   No
# 3186-AJIEK                   Yes                   No                  Yes
#
#                     Tech Support         Streaming TV     Streaming Movies  \
# Customer ID
# 0052-YNYOT   No internet service  No internet service  No internet service
# 6304-IJFSQ                    No                   No                   No
# 9586-JGQKH                   Yes                  Yes                  Yes
# 4501-VCPFK                   Yes                   No                   No
# 6075-SLNIL                    No                   No                  Yes
# 9347-AERRL   No internet service  No internet service  No internet service
# 0093-XWZFY                    No                  Yes                  Yes
# 2274-XUATA                   Yes                  Yes                  Yes
# 1980-KXVPM                    No                   No                   No
# 7703-ZEKEF                    No                   No                   No
# 0723-DRCLG                    No                   No                   No
# 5482-NUPNA                   Yes                   No                   No
# 6691-CCIHA                   Yes                  Yes                  Yes
# 1685-BQULA                    No                  Yes                   No
# 9053-EJUNL                    No                  Yes                   No
# 0666-UXTJO                    No                  Yes                   No
# 1471-GIQKQ                    No                   No                   No
# 4807-IZYOZ   No internet service  No internet service  No internet service
# 1122-JWTJW                    No                   No                   No
# 9710-NJERN   No internet service  No internet service  No internet service
# 9837-FWLCH   No internet service  No internet service  No internet service
# 1699-HPSBG                   Yes                  Yes                   No
# 7203-OYKCT                    No                  Yes                  Yes
# 1035-IPQPU                    No                  Yes                  Yes
# 7398-LXGYX                    No                   No                   No
# 2823-LKABH                   Yes                   No                  Yes
# 8775-CEBBJ                    No                   No                   No
# 0550-DCXLH                   Yes                  Yes                  Yes
# 9281-CEDRU                   Yes                  Yes                   No
# 2235-DWLJU                    No                  Yes                  Yes
# 0871-OPBXW   No internet service  No internet service  No internet service
# 3605-JISKB                    No                   No                   No
# 6894-LFHLY                    No                   No                   No
# 9767-FFLEM                    No                   No                   No
# 0639-TSIQW                    No                  Yes                   No
# 8456-QDAVC                    No                  Yes                   No
# 7750-EYXWZ                   Yes                  Yes                  Yes
# 2569-WGERO   No internet service  No internet service  No internet service
# 6840-RESVB                   Yes                  Yes                  Yes
# 2234-XADUH                    No                  Yes                  Yes
# 4801-JZAZL                    No                   No                   No
# 8361-LTMKD                    No                   No                   No
# 3186-AJIEK                   Yes                  Yes                  Yes
#
#                    Contract Paperless Billing             Payment Method  \
# Customer ID
# 0052-YNYOT         One year                No           Electronic check
# 6304-IJFSQ   Month-to-month               Yes               Mailed check
# 9586-JGQKH         Two year               Yes  Bank transfer (automatic)
# 4501-VCPFK   Month-to-month                No           Electronic check
# 6075-SLNIL   Month-to-month               Yes    Credit card (automatic)
# 9347-AERRL         One year                No    Credit card (automatic)
# 0093-XWZFY   Month-to-month               Yes    Credit card (automatic)
# 2274-XUATA         Two year               Yes  Bank transfer (automatic)
# 1980-KXVPM   Month-to-month               Yes    Credit card (automatic)
# 7703-ZEKEF   Month-to-month               Yes           Electronic check
# 0723-DRCLG   Month-to-month               Yes           Electronic check
# 5482-NUPNA   Month-to-month               Yes               Mailed check
# 6691-CCIHA         Two year               Yes           Electronic check
# 1685-BQULA   Month-to-month               Yes  Bank transfer (automatic)
# 9053-EJUNL   Month-to-month               Yes           Electronic check
# 0666-UXTJO   Month-to-month               Yes    Credit card (automatic)
# 1471-GIQKQ   Month-to-month                No           Electronic check
# 4807-IZYOZ         Two year                No  Bank transfer (automatic)
# 1122-JWTJW   Month-to-month               Yes               Mailed check
# 9710-NJERN         Two year                No               Mailed check
# 9837-FWLCH   Month-to-month               Yes           Electronic check
# 1699-HPSBG         One year               Yes           Electronic check
# 7203-OYKCT         One year               Yes           Electronic check
# 1035-IPQPU   Month-to-month               Yes           Electronic check
# 7398-LXGYX   Month-to-month               Yes    Credit card (automatic)
# 2823-LKABH   Month-to-month               Yes  Bank transfer (automatic)
# 8775-CEBBJ   Month-to-month               Yes  Bank transfer (automatic)
# 0550-DCXLH   Month-to-month                No               Mailed check
# 9281-CEDRU         Two year                No  Bank transfer (automatic)
# 2235-DWLJU   Month-to-month               Yes           Electronic check
# 0871-OPBXW   Month-to-month               Yes               Mailed check
# 3605-JISKB         One year                No    Credit card (automatic)
# 6894-LFHLY   Month-to-month               Yes           Electronic check
# 9767-FFLEM   Month-to-month               Yes    Credit card (automatic)
# 0639-TSIQW   Month-to-month               Yes    Credit card (automatic)
# 8456-QDAVC   Month-to-month               Yes  Bank transfer (automatic)
# 7750-EYXWZ         One year                No           Electronic check
# 2569-WGERO         Two year               Yes  Bank transfer (automatic)
# 6840-RESVB         One year               Yes               Mailed check
# 2234-XADUH         One year               Yes    Credit card (automatic)
# 4801-JZAZL   Month-to-month               Yes           Electronic check
# 8361-LTMKD   Month-to-month               Yes               Mailed check
# 3186-AJIEK         Two year               Yes  Bank transfer (automatic)
#
#              Monthly Charges Total Charges Churn
# Customer ID
# 0052-YNYOT             20.55        1343.4    No
# 6304-IJFSQ             49.90         130.1   Yes
# 9586-JGQKH            105.40       6794.75    No
# 4501-VCPFK             35.75        1022.5    No
# 6075-SLNIL             95.10        3691.2    No
# 9347-AERRL             19.30         486.2    No
# 0093-XWZFY            104.50       4036.85   Yes
# 2274-XUATA             63.10       4685.55    No
# 1980-KXVPM             75.05        256.25   Yes
# 7703-ZEKEF             81.00        1917.1   Yes
# 0723-DRCLG             74.45         74.45   Yes
# 5482-NUPNA             60.40        272.15   Yes
# 6691-CCIHA             84.95       5150.55    No
# 1685-BQULA             93.40        3756.4    No
# 9053-EJUNL             89.20       3645.75    No
# 0666-UXTJO             85.20       2874.45    No
# 1471-GIQKQ             49.95         49.95    No
# 4807-IZYOZ             20.65       1020.75    No
# 1122-JWTJW             70.65         70.65   Yes
# 9710-NJERN             20.15           826    No
# 9837-FWLCH             19.20           239    No
# 1699-HPSBG             59.80         727.8   Yes
# 7203-OYKCT            104.95        7544.3    No
# 1035-IPQPU            103.50        6479.4    No
# 7398-LXGYX             84.80       3626.35    No
# 2823-LKABH             95.05        1679.4    No
# 8775-CEBBJ             44.20        403.35   Yes
# 0550-DCXLH             73.35        931.55    No
# 9281-CEDRU             64.10       4326.25    No
# 2235-DWLJU             44.40        263.05    No
# 0871-OPBXW             20.05         39.25    No
# 3605-JISKB             60.00        3316.1    No
# 6894-LFHLY             75.75         75.75   Yes
# 9767-FFLEM             69.50       2625.25    No
# 0639-TSIQW            102.95       6886.25   Yes
# 8456-QDAVC             78.70        1495.1    No
# 7750-EYXWZ             60.65         743.3    No
# 2569-WGERO             21.15        1419.4    No
# 6840-RESVB             84.80        1990.5    No
# 2234-XADUH            103.20        7362.9    No
# 4801-JZAZL             29.60        346.45    No
# 8361-LTMKD             74.40         306.6   Yes
# 3186-AJIEK            105.65        6844.5    No

# %%
# Accessing a specific row using iloc
df.iloc[7000:7005]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 0052-YNYOT      368391             No      No         No      67
# 6304-IJFSQ      729518             No      No         No       3
# 9586-JGQKH      236749             No     Yes         No      64
# 4501-VCPFK      406608             No      No         No      26
# 6075-SLNIL      889198             No      No         No      38
#
#             Phone Service    Multiple Lines Internet Service  \
# Customer ID
# 0052-YNYOT            Yes                No               No
# 6304-IJFSQ            Yes                No              DSL
# 9586-JGQKH            Yes               Yes      Fiber optic
# 4501-VCPFK             No  No phone service              DSL
# 6075-SLNIL            Yes               Yes      Fiber optic
#
#                  Online Security        Online Backup    Device Protection  \
# Customer ID
# 0052-YNYOT   No internet service  No internet service  No internet service
# 6304-IJFSQ                    No                  Yes                   No
# 9586-JGQKH                    No                  Yes                   No
# 4501-VCPFK                    No                   No                  Yes
# 6075-SLNIL                    No                  Yes                  Yes
#
#                     Tech Support         Streaming TV     Streaming Movies  \
# Customer ID
# 0052-YNYOT   No internet service  No internet service  No internet service
# 6304-IJFSQ                    No                   No                   No
# 9586-JGQKH                   Yes                  Yes                  Yes
# 4501-VCPFK                   Yes                   No                   No
# 6075-SLNIL                    No                   No                  Yes
#
#                    Contract Paperless Billing             Payment Method  \
# Customer ID
# 0052-YNYOT         One year                No           Electronic check
# 6304-IJFSQ   Month-to-month               Yes               Mailed check
# 9586-JGQKH         Two year               Yes  Bank transfer (automatic)
# 4501-VCPFK   Month-to-month                No           Electronic check
# 6075-SLNIL   Month-to-month               Yes    Credit card (automatic)
#
#              Monthly Charges Total Charges Churn
# Customer ID
# 0052-YNYOT             20.55        1343.4    No
# 6304-IJFSQ             49.90         130.1   Yes
# 9586-JGQKH            105.40       6794.75    No
# 4501-VCPFK             35.75        1022.5    No
# 6075-SLNIL             95.10        3691.2    No

# %%
# Accessing more than one row using loc
x= df.loc[['7590-VHVEG','5575-GNVDE','3668-QPYBK']]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 7590-VHVEG      318537             No     Yes         No       1
# 5575-GNVDE      152148             No      No         No      34
# 3668-QPYBK      326527             No      No         No       2
#
#             Phone Service    Multiple Lines Internet Service Online Security  \
# Customer ID
# 7590-VHVEG             No  No phone service              DSL              No
# 5575-GNVDE            Yes                No              DSL             Yes
# 3668-QPYBK            Yes                No              DSL             Yes
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 7590-VHVEG            Yes                No           No           No
# 5575-GNVDE             No               Yes           No           No
# 3668-QPYBK            Yes                No           No           No
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 7590-VHVEG                No  Month-to-month               Yes
# 5575-GNVDE                No        One year                No
# 3668-QPYBK                No  Month-to-month               Yes
#
#                Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 7590-VHVEG   Electronic check            29.85         29.85    No
# 5575-GNVDE       Mailed check            56.95        1889.5    No
# 3668-QPYBK       Mailed check            53.85        108.15   Yes

# %%
df.iloc[[1000,4050,2139]]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 8357-EQXFO      564307             No      No         No       7
# 2675-DHUTR      763124            Yes     Yes         No      58
# 8160-HOWOX      414698             No      No         No       7
#
#             Phone Service Multiple Lines Internet Service Online Security  \
# Customer ID
# 8357-EQXFO            Yes             No      Fiber optic              No
# 2675-DHUTR            Yes            Yes      Fiber optic              No
# 8160-HOWOX            Yes             No              DSL              No
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 8357-EQXFO             No               Yes           No          Yes
# 2675-DHUTR            Yes                No           No          Yes
# 8160-HOWOX             No                No           No          Yes
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 8357-EQXFO               Yes  Month-to-month               Yes
# 2675-DHUTR               Yes  Month-to-month               Yes
# 8160-HOWOX               Yes  Month-to-month               Yes
#
#                Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 8357-EQXFO   Electronic check            95.35         660.9   Yes
# 2675-DHUTR   Electronic check            98.90        5780.7    No
# 8160-HOWOX   Electronic check            66.85         458.1    No

# %% [markdown]
# That was row selection. This row selection doesn't seem that different to Square brackets
# selection. However, what makes loc so powerful is that you can extend your selection with the desired columns as shown below:

# %%
df.loc[["5575-GNVDE","3668-QPYBK"],["Partner","Contract"]]
# Out:
#             Partner        Contract
# Customer ID
# 5575-GNVDE       No        One year
# 3668-QPYBK       No  Month-to-month

# %%
df.loc[["5575-GNVDE","3668-QPYBK"],["LoyaltyID",'Senior Citizen','Churn']]
# Out:
#              LoyaltyID Senior Citizen Churn
# Customer ID
# 5575-GNVDE      152148             No    No
# 3668-QPYBK      326527             No   Yes

# %% [markdown]
# Notice how with column selection using loc, we use the actual labels. Observe the difference
# with iloc as shown below :

# %%
## use loc to get two rows and two columns
df.loc["5575-GNVDE":"9959-WOFKT",["Churn","Partner"]]
# Out:
#             Churn Partner
# Customer ID
# 5575-GNVDE     No      No
# 3668-QPYBK    Yes      No
# 7795-CFOCW     No      No
# 9237-HQITU    Yes      No
# 9305-CDSKC    Yes      No
# 1452-KIOVK     No      No
# 6713-OKOMC     No      No
# 7892-POOKP    Yes     Yes
# 6388-TABGU     No      No
# 9763-GRSKD     No     Yes
# 7469-LKBCI     No      No
# 8091-TTVAX     No     Yes
# 0280-XJGEX    Yes      No
# 5129-JLPIS     No      No
# 3655-SNQYZ     No     Yes
# 8191-XWSZG     No      No
# 9959-WOFKT     No      No

# %%
df.iloc[0:6,4:9]
# Out:
#              Tenure Phone Service    Multiple Lines Internet Service  \
# Customer ID
# 7590-VHVEG        1            No  No phone service              DSL
# 5575-GNVDE       34           Yes                No              DSL
# 3668-QPYBK        2           Yes                No              DSL
# 7795-CFOCW       45            No  No phone service              DSL
# 9237-HQITU        2           Yes                No      Fiber optic
# 9305-CDSKC        8           Yes               Yes      Fiber optic
#
#             Online Security
# Customer ID
# 7590-VHVEG               No
# 5575-GNVDE              Yes
# 3668-QPYBK              Yes
# 7795-CFOCW              Yes
# 9237-HQITU               No
# 9305-CDSKC               No

# %%
#Practice getting a range of values 
df.loc["5575-GNVDE":"9959-WOFKT","Phone Service":"Online Security"]
# Out:
#             Phone Service    Multiple Lines Internet Service  \
# Customer ID
# 5575-GNVDE            Yes                No              DSL
# 3668-QPYBK            Yes                No              DSL
# 7795-CFOCW             No  No phone service              DSL
# 9237-HQITU            Yes                No      Fiber optic
# 9305-CDSKC            Yes               Yes      Fiber optic
# 1452-KIOVK            Yes               Yes      Fiber optic
# 6713-OKOMC             No  No phone service              DSL
# 7892-POOKP            Yes               Yes      Fiber optic
# 6388-TABGU            Yes                No              DSL
# 9763-GRSKD            Yes                No              DSL
# 7469-LKBCI            Yes                No               No
# 8091-TTVAX            Yes               Yes      Fiber optic
# 0280-XJGEX            Yes               Yes      Fiber optic
# 5129-JLPIS            Yes                No      Fiber optic
# 3655-SNQYZ            Yes               Yes      Fiber optic
# 8191-XWSZG            Yes                No               No
# 9959-WOFKT            Yes               Yes      Fiber optic
#
#                  Online Security
# Customer ID
# 5575-GNVDE                   Yes
# 3668-QPYBK                   Yes
# 7795-CFOCW                   Yes
# 9237-HQITU                    No
# 9305-CDSKC                    No
# 1452-KIOVK                    No
# 6713-OKOMC                   Yes
# 7892-POOKP                    No
# 6388-TABGU                   Yes
# 9763-GRSKD                   Yes
# 7469-LKBCI   No internet service
# 8091-TTVAX                    No
# 0280-XJGEX                    No
# 5129-JLPIS                   Yes
# 3655-SNQYZ                   Yes
# 8191-XWSZG   No internet service
# 9959-WOFKT                   Yes

# %%
df.iloc[4:9,0:4]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents
# Customer ID
# 9237-HQITU      503388             No      No         No
# 9305-CDSKC      160192             No      No         No
# 1452-KIOVK      680623             No      No        Yes
# 6713-OKOMC      340874             No      No         No
# 7892-POOKP      582674             No     Yes         No

# %%
## Select a list of rows and Senior Citizen Partner Dependents using iloc
df.iloc[0:4,1:4]
# Out:
#             Senior Citizen Partner Dependents
# Customer ID
# 7590-VHVEG              No     Yes         No
# 5575-GNVDE              No      No         No
# 3668-QPYBK              No      No         No
# 7795-CFOCW              No      No         No

# %% [markdown]
# ## Filtering

# %% [markdown]
# More often than not, as a data scientist you will be required to filter your data. For example, you might want to just return a dataframe that has individuals above a certain age, or of a certain gender or products above a certain price etc. You can be able to do this with Pandas.

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Dependents',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'Tech Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn'],
#       dtype='object')

# %%
x=[2,3,4,5]

# %%
df['Churn']
# Out:
# Customer ID
# 7590-VHVEG     No
# 5575-GNVDE     No
# 3668-QPYBK    Yes
# 7795-CFOCW     No
# 9237-HQITU    Yes
#              ...
# 6840-RESVB     No
# 2234-XADUH     No
# 4801-JZAZL     No
# 8361-LTMKD    Yes
# 3186-AJIEK     No
# Name: Churn, Length: 7043, dtype: object

# %%
df['Internet Service'].unique()
# Out:
# array(['DSL', 'Fiber optic', 'No'], dtype=object)

# %%
df['Internet Service'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: Internet Service, dtype: int64

# %% [markdown]
# This returns a series object with a bunch of Boolean Values where the value is true if that particular condition is met

# %% [markdown]
#  == Exact Match
#
#  > Greater than
#
#  >= Greater than or equal to
#
#  <= Equal to or less than
#  < less than
#
#  & And
#  | or
#  ~ Not

# %%
df['Contract'].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
filt=df["Internet Service"]=="DSL"
df[~filt]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 9237-HQITU      503388             No      No         No       2
# 9305-CDSKC      160192             No      No         No       8
# 1452-KIOVK      680623             No      No        Yes      22
# 7892-POOKP      582674             No     Yes         No      28
# 7469-LKBCI      185808             No      No         No      16
# ...                ...            ...     ...        ...     ...
# 8456-QDAVC      956970             No      No         No      19
# 2569-WGERO      852094             No      No         No      72
# 2234-XADUH      230811             No     Yes        Yes      72
# 8361-LTMKD      731782            Yes     Yes         No       4
# 3186-AJIEK      353947             No      No         No      66
#
#             Phone Service Multiple Lines Internet Service  \
# Customer ID
# 9237-HQITU            Yes             No      Fiber optic
# 9305-CDSKC            Yes            Yes      Fiber optic
# 1452-KIOVK            Yes            Yes      Fiber optic
# 7892-POOKP            Yes            Yes      Fiber optic
# 7469-LKBCI            Yes             No               No
# ...                   ...            ...              ...
# 8456-QDAVC            Yes             No      Fiber optic
# 2569-WGERO            Yes             No               No
# 2234-XADUH            Yes            Yes      Fiber optic
# 8361-LTMKD            Yes            Yes      Fiber optic
# 3186-AJIEK            Yes             No      Fiber optic
#
#                  Online Security        Online Backup    Device Protection  \
# Customer ID
# 9237-HQITU                    No                   No                   No
# 9305-CDSKC                    No                   No                  Yes
# 1452-KIOVK                    No                  Yes                   No
# 7892-POOKP                    No                   No                  Yes
# 7469-LKBCI   No internet service  No internet service  No internet service
# ...                          ...                  ...                  ...
# 8456-QDAVC                    No                   No                   No
# 2569-WGERO   No internet service  No internet service  No internet service
# 2234-XADUH                    No                  Yes                  Yes
# 8361-LTMKD                    No                   No                   No
# 3186-AJIEK                   Yes                   No                  Yes
#
#                     Tech Support         Streaming TV     Streaming Movies  \
# Customer ID
# 9237-HQITU                    No                   No                   No
# 9305-CDSKC                    No                  Yes                  Yes
# 1452-KIOVK                    No                  Yes                   No
# 7892-POOKP                   Yes                  Yes                  Yes
# 7469-LKBCI   No internet service  No internet service  No internet service
# ...                          ...                  ...                  ...
# 8456-QDAVC                    No                  Yes                   No
# 2569-WGERO   No internet service  No internet service  No internet service
# 2234-XADUH                    No                  Yes                  Yes
# 8361-LTMKD                    No                   No                   No
# 3186-AJIEK                   Yes                  Yes                  Yes
#
#                    Contract Paperless Billing             Payment Method  \
# Customer ID
# 9237-HQITU   Month-to-month               Yes           Electronic check
# 9305-CDSKC   Month-to-month               Yes           Electronic check
# 1452-KIOVK   Month-to-month               Yes    Credit card (automatic)
# 7892-POOKP   Month-to-month               Yes           Electronic check
# 7469-LKBCI         Two year                No    Credit card (automatic)
# ...                     ...               ...                        ...
# 8456-QDAVC   Month-to-month               Yes  Bank transfer (automatic)
# 2569-WGERO         Two year               Yes  Bank transfer (automatic)
# 2234-XADUH         One year               Yes    Credit card (automatic)
# 8361-LTMKD   Month-to-month               Yes               Mailed check
# 3186-AJIEK         Two year               Yes  Bank transfer (automatic)
#
#              Monthly Charges Total Charges Churn
# Customer ID
# 9237-HQITU             70.70        151.65   Yes
# 9305-CDSKC             99.65         820.5   Yes
# 1452-KIOVK             89.10        1949.4    No
# 7892-POOKP            104.80       3046.05   Yes
# 7469-LKBCI             18.95         326.8    No
# ...                      ...           ...   ...
# 8456-QDAVC             78.70        1495.1    No
# 2569-WGERO             21.15        1419.4    No
# 2234-XADUH            103.20        7362.9    No
# 8361-LTMKD             74.40         306.6   Yes
# 3186-AJIEK            105.65        6844.5    No
#
# [4622 rows x 20 columns]

# %%
df[df['Contract']== 'One year']
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 5575-GNVDE      152148             No      No         No      34
# 7795-CFOCW      845894             No      No         No      45
# 6388-TABGU      303784             No      No        Yes      62
# 8091-TTVAX      158680             No     Yes         No      58
# 8191-XWSZG      698246             No      No         No      52
# ...                ...            ...     ...        ...     ...
# 7203-OYKCT      482402             No      No         No      72
# 3605-JISKB      847238            Yes     Yes         No      55
# 7750-EYXWZ      210184             No      No         No      12
# 6840-RESVB      810338             No     Yes        Yes      24
# 2234-XADUH      230811             No     Yes        Yes      72
#
#             Phone Service    Multiple Lines Internet Service  \
# Customer ID
# 5575-GNVDE            Yes                No              DSL
# 7795-CFOCW             No  No phone service              DSL
# 6388-TABGU            Yes                No              DSL
# 8091-TTVAX            Yes               Yes      Fiber optic
# 8191-XWSZG            Yes                No               No
# ...                   ...               ...              ...
# 7203-OYKCT            Yes               Yes      Fiber optic
# 3605-JISKB            Yes               Yes              DSL
# 7750-EYXWZ             No  No phone service              DSL
# 6840-RESVB            Yes               Yes              DSL
# 2234-XADUH            Yes               Yes      Fiber optic
#
#                  Online Security        Online Backup    Device Protection  \
# Customer ID
# 5575-GNVDE                   Yes                   No                  Yes
# 7795-CFOCW                   Yes                   No                  Yes
# 6388-TABGU                   Yes                  Yes                   No
# 8091-TTVAX                    No                   No                  Yes
# 8191-XWSZG   No internet service  No internet service  No internet service
# ...                          ...                  ...                  ...
# 7203-OYKCT                    No                  Yes                  Yes
# 3605-JISKB                   Yes                  Yes                   No
# 7750-EYXWZ                    No                  Yes                  Yes
# 6840-RESVB                   Yes                   No                  Yes
# 2234-XADUH                    No                  Yes                  Yes
#
#                     Tech Support         Streaming TV     Streaming Movies  \
# Customer ID
# 5575-GNVDE                    No                   No                   No
# 7795-CFOCW                   Yes                   No                   No
# 6388-TABGU                    No                   No                   No
# 8091-TTVAX                    No                  Yes                  Yes
# 8191-XWSZG   No internet service  No internet service  No internet service
# ...                          ...                  ...                  ...
# 7203-OYKCT                    No                  Yes                  Yes
# 3605-JISKB                    No                   No                   No
# 7750-EYXWZ                   Yes                  Yes                  Yes
# 6840-RESVB                   Yes                  Yes                  Yes
# 2234-XADUH                    No                  Yes                  Yes
#
#              Contract Paperless Billing             Payment Method  \
# Customer ID
# 5575-GNVDE   One year                No               Mailed check
# 7795-CFOCW   One year                No  Bank transfer (automatic)
# 6388-TABGU   One year                No  Bank transfer (automatic)
# 8091-TTVAX   One year                No    Credit card (automatic)
# 8191-XWSZG   One year                No               Mailed check
# ...               ...               ...                        ...
# 7203-OYKCT   One year               Yes           Electronic check
# 3605-JISKB   One year                No    Credit card (automatic)
# 7750-EYXWZ   One year                No           Electronic check
# 6840-RESVB   One year               Yes               Mailed check
# 2234-XADUH   One year               Yes    Credit card (automatic)
#
#              Monthly Charges Total Charges Churn
# Customer ID
# 5575-GNVDE             56.95        1889.5    No
# 7795-CFOCW             42.30       1840.75    No
# 6388-TABGU             56.15       3487.95    No
# 8091-TTVAX            100.35        5681.1    No
# 8191-XWSZG             20.65       1022.95    No
# ...                      ...           ...   ...
# 7203-OYKCT            104.95        7544.3    No
# 3605-JISKB             60.00        3316.1    No
# 7750-EYXWZ             60.65         743.3    No
# 6840-RESVB             84.80        1990.5    No
# 2234-XADUH            103.20        7362.9    No
#
# [1473 rows x 20 columns]

# %%
## Exact Match
filt=df['Internet Service']=='Fiber optic'
df[filt]


## Whose Contract is not a month to month contract
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 9237-HQITU      503388             No      No         No       2
# 9305-CDSKC      160192             No      No         No       8
# 1452-KIOVK      680623             No      No        Yes      22
# 7892-POOKP      582674             No     Yes         No      28
# 8091-TTVAX      158680             No     Yes         No      58
# ...                ...            ...     ...        ...     ...
# 0639-TSIQW      175841             No      No         No      67
# 8456-QDAVC      956970             No      No         No      19
# 2234-XADUH      230811             No     Yes        Yes      72
# 8361-LTMKD      731782            Yes     Yes         No       4
# 3186-AJIEK      353947             No      No         No      66
#
#             Phone Service Multiple Lines Internet Service Online Security  \
# Customer ID
# 9237-HQITU            Yes             No      Fiber optic              No
# 9305-CDSKC            Yes            Yes      Fiber optic              No
# 1452-KIOVK            Yes            Yes      Fiber optic              No
# 7892-POOKP            Yes            Yes      Fiber optic              No
# 8091-TTVAX            Yes            Yes      Fiber optic              No
# ...                   ...            ...              ...             ...
# 0639-TSIQW            Yes            Yes      Fiber optic             Yes
# 8456-QDAVC            Yes             No      Fiber optic              No
# 2234-XADUH            Yes            Yes      Fiber optic              No
# 8361-LTMKD            Yes            Yes      Fiber optic              No
# 3186-AJIEK            Yes             No      Fiber optic             Yes
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 9237-HQITU             No                No           No           No
# 9305-CDSKC             No               Yes           No          Yes
# 1452-KIOVK            Yes                No           No          Yes
# 7892-POOKP             No               Yes          Yes          Yes
# 8091-TTVAX             No               Yes           No          Yes
# ...                   ...               ...          ...          ...
# 0639-TSIQW            Yes               Yes           No          Yes
# 8456-QDAVC             No                No           No          Yes
# 2234-XADUH            Yes               Yes           No          Yes
# 8361-LTMKD             No                No           No           No
# 3186-AJIEK             No               Yes          Yes          Yes
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 9237-HQITU                No  Month-to-month               Yes
# 9305-CDSKC               Yes  Month-to-month               Yes
# 1452-KIOVK                No  Month-to-month               Yes
# 7892-POOKP               Yes  Month-to-month               Yes
# 8091-TTVAX               Yes        One year                No
# ...                      ...             ...               ...
# 0639-TSIQW                No  Month-to-month               Yes
# 8456-QDAVC                No  Month-to-month               Yes
# 2234-XADUH               Yes        One year               Yes
# 8361-LTMKD                No  Month-to-month               Yes
# 3186-AJIEK               Yes        Two year               Yes
#
#                         Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 9237-HQITU            Electronic check            70.70        151.65   Yes
# 9305-CDSKC            Electronic check            99.65         820.5   Yes
# 1452-KIOVK     Credit card (automatic)            89.10        1949.4    No
# 7892-POOKP            Electronic check           104.80       3046.05   Yes
# 8091-TTVAX     Credit card (automatic)           100.35        5681.1    No
# ...                                ...              ...           ...   ...
# 0639-TSIQW     Credit card (automatic)           102.95       6886.25   Yes
# 8456-QDAVC   Bank transfer (automatic)            78.70        1495.1    No
# 2234-XADUH     Credit card (automatic)           103.20        7362.9    No
# 8361-LTMKD                Mailed check            74.40         306.6   Yes
# 3186-AJIEK   Bank transfer (automatic)           105.65        6844.5    No
#
# [3096 rows x 20 columns]

# %% [markdown]
# If we wanted to get the opposite of the filter for example if we wanted to get a dataframe without any females:

# %%
filt = (df['Internet Service']=='Fiber optic')
df[~filt]
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Dependents  Tenure  \
# 0        318537  7590-VHVEG             No     Yes         No       1
# 1        152148  5575-GNVDE             No      No         No      34
# 2        326527  3668-QPYBK             No      No         No       2
# 3        845894  7795-CFOCW             No      No         No      45
# 7        340874  6713-OKOMC             No      No         No      10
# ...         ...         ...            ...     ...        ...     ...
# 7031     847238  3605-JISKB            Yes     Yes         No      55
# 7036     210184  7750-EYXWZ             No      No         No      12
# 7037     852094  2569-WGERO             No      No         No      72
# 7038     810338  6840-RESVB             No     Yes        Yes      24
# 7040     155157  4801-JZAZL             No     Yes        Yes      11
#
#      Phone Service    Multiple Lines Internet Service      Online Security  \
# 0               No  No phone service              DSL                   No
# 1              Yes                No              DSL                  Yes
# 2              Yes                No              DSL                  Yes
# 3               No  No phone service              DSL                  Yes
# 7               No  No phone service              DSL                  Yes
# ...            ...               ...              ...                  ...
# 7031           Yes               Yes              DSL                  Yes
# 7036            No  No phone service              DSL                   No
# 7037           Yes                No               No  No internet service
# 7038           Yes               Yes              DSL                  Yes
# 7040            No  No phone service              DSL                  Yes
#
#       ...    Device Protection         Tech Support         Streaming TV  \
# 0     ...                   No                   No                   No
# 1     ...                  Yes                   No                   No
# 2     ...                   No                   No                   No
# 3     ...                  Yes                  Yes                   No
# 7     ...                   No                   No                   No
# ...   ...                  ...                  ...                  ...
# 7031  ...                   No                   No                   No
# 7036  ...                  Yes                  Yes                  Yes
# 7037  ...  No internet service  No internet service  No internet service
# 7038  ...                  Yes                  Yes                  Yes
# 7040  ...                   No                   No                   No
#
#          Streaming Movies        Contract Paperless Billing  \
# 0                      No  Month-to-month               Yes
# 1                      No        One year                No
# 2                      No  Month-to-month               Yes
# 3                      No        One year                No
# 7                      No  Month-to-month                No
# ...                   ...             ...               ...
# 7031                   No        One year                No
# 7036                  Yes        One year                No
# 7037  No internet service        Two year               Yes
# 7038                  Yes        One year               Yes
# 7040                   No  Month-to-month               Yes
#
#                  Payment Method Monthly Charges  Total Charges Churn
# 0              Electronic check           29.85          29.85    No
# 1                  Mailed check           56.95         1889.5    No
# 2                  Mailed check           53.85         108.15   Yes
# 3     Bank transfer (automatic)           42.30        1840.75    No
# 7                  Mailed check           29.75          301.9    No
# ...                         ...             ...            ...   ...
# 7031    Credit card (automatic)           60.00         3316.1    No
# 7036           Electronic check           60.65          743.3    No
# 7037  Bank transfer (automatic)           21.15         1419.4    No
# 7038               Mailed check           84.80         1990.5    No
# 7040           Electronic check           29.60         346.45    No
#
# [3947 rows x 21 columns]

# %%
# Questions

#return the last 20 Senior Citizens in the dataframe.
#Return a dataframe showing only the customers that churned.
#Return a dataframe with customers whose tenure is > 50.
#Return a dataframe with customers without dependents.

# %%
df.tail(2)
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Children  Tenure  \
# 7041     731782  8361-LTMKD            Yes     Yes       No       4
# 7042     353947  3186-AJIEK             No      No       No      66
#
#      Phone Service Multiple Lines Internet Service Online Security  ...  \
# 7041           Yes            Yes      Fiber optic              No  ...
# 7042           Yes             No      Fiber optic             Yes  ...
#
#      IT Support Streaming TV Streaming Movies        Contract  \
# 7041         No           No               No  Month-to-month
# 7042        Yes          Yes              Yes        Two year
#
#      Paperless Billing             Payment Method Monthly Charges  \
# 7041               Yes               Mailed check           74.40
# 7042               Yes  Bank transfer (automatic)          105.65
#
#      Total Charges  Churn           IS
# 7041         306.6    Yes  Fiber optic
# 7042        6844.5     No  Fiber optic
#
# [2 rows x 22 columns]

# %%
#Return a dataframe showing only the customers that churned.
df[df['Churn']=='Yes']
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Children  Tenure  \
# 2        326527  3668-QPYBK             No      No       No       2
# 4        503388  9237-HQITU             No      No       No       2
# 5        160192  9305-CDSKC             No      No       No       8
# 8        582674  7892-POOKP             No     Yes       No      28
# 13       933642  0280-XJGEX             No      No       No      49
# ...         ...         ...            ...     ...      ...     ...
# 7021     265508  1699-HPSBG             No      No       No      12
# 7026     773737  8775-CEBBJ             No      No       No       9
# 7032     137858  6894-LFHLY            Yes      No       No       1
# 7034     175841  0639-TSIQW             No      No       No      67
# 7041     731782  8361-LTMKD            Yes     Yes       No       4
#
#      Phone Service Multiple Lines Internet Service Online Security  ...  \
# 2              Yes             No              DSL             Yes  ...
# 4              Yes             No      Fiber optic              No  ...
# 5              Yes            Yes      Fiber optic              No  ...
# 8              Yes            Yes      Fiber optic              No  ...
# 13             Yes            Yes      Fiber optic              No  ...
# ...            ...            ...              ...             ...  ...
# 7021           Yes             No              DSL              No  ...
# 7026           Yes             No              DSL              No  ...
# 7032           Yes            Yes      Fiber optic              No  ...
# 7034           Yes            Yes      Fiber optic             Yes  ...
# 7041           Yes            Yes      Fiber optic              No  ...
#
#      IT Support Streaming TV Streaming Movies        Contract  \
# 2            No           No               No  Month-to-month
# 4            No           No               No  Month-to-month
# 5            No          Yes              Yes  Month-to-month
# 8           Yes          Yes              Yes  Month-to-month
# 13           No          Yes              Yes  Month-to-month
# ...         ...          ...              ...             ...
# 7021        Yes          Yes               No        One year
# 7026         No           No               No  Month-to-month
# 7032         No           No               No  Month-to-month
# 7034         No          Yes               No  Month-to-month
# 7041         No           No               No  Month-to-month
#
#      Paperless Billing             Payment Method Monthly Charges  \
# 2                  Yes               Mailed check           53.85
# 4                  Yes           Electronic check           70.70
# 5                  Yes           Electronic check           99.65
# 8                  Yes           Electronic check          104.80
# 13                 Yes  Bank transfer (automatic)          103.70
# ...                ...                        ...             ...
# 7021               Yes           Electronic check           59.80
# 7026               Yes  Bank transfer (automatic)           44.20
# 7032               Yes           Electronic check           75.75
# 7034               Yes    Credit card (automatic)          102.95
# 7041               Yes               Mailed check           74.40
#
#      Total Charges  Churn           IS
# 2           108.15    Yes          DSL
# 4           151.65    Yes  Fiber optic
# 5           820.50    Yes  Fiber optic
# 8          3046.05    Yes  Fiber optic
# 13         5036.30    Yes  Fiber optic
# ...            ...    ...          ...
# 7021        727.80    Yes          DSL
# 7026        403.35    Yes          DSL
# 7032         75.75    Yes  Fiber optic
# 7034       6886.25    Yes  Fiber optic
# 7041        306.60    Yes  Fiber optic
#
# [1869 rows x 22 columns]

# %% [markdown]
# ## Convert to DataType

# %% [markdown]
# ## Cleaning

# %% [markdown]
# The difference between fake data and real-world data is that real data is rarely clean and homogeneous. One particular issue that we need to tackle when working with real data is that of missing values. And it’s not just about values being missing, different data sources can indicate missing values in different ways as well.

# %% [markdown]
# The two flavors in which we are likely to encounter missing or null values are:
#
# - None: A Python object that is often used for missing data in Python. None can only be used in arrays with data type ‘object’ (i.e., arrays of Python objects).
#
# - NaN (Not a Number): A special floating-point value that is used to represent missing data. A floating-point type means that, unlike with None’s object array, we can perform mathematical operations. However, remember that, regardless of the operation, the result of arithmetic with NaN will be another NaN. operations. However, remember that, regardless of the operation, the result of arithmetic with NaN will be another NaN.

# %% [markdown]
# Pandas is built to handle both NaN and None, and it treats the two as essentially interchangeable for indicating missing or null values. Pandas also provides us with many useful methods for detecting, removing, and replacing null values in Pandas data structures: isnull(), notnull(), dropna(), and fillna().

# %% [markdown]
# The None keyword is used to define a null value, or no value at all.
#
# None is not the same as 0, False, or an empty string. None is a data type of its own (NoneType) and only None can be None.

# %%
df.isnull().sum()
# Out:
# LoyaltyID            0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %% [markdown]
# ## Detecting Null Values

# %%
df.isnull()
# Out:
#              LoyaltyID  Senior Citizen  Partner  Dependents  Tenure  \
# Customer ID
# 7590-VHVEG       False           False    False       False   False
# 5575-GNVDE       False           False    False       False   False
# 3668-QPYBK       False           False    False       False   False
# 7795-CFOCW       False           False    False       False   False
# 9237-HQITU       False           False    False       False   False
# ...                ...             ...      ...         ...     ...
# 6840-RESVB       False           False    False       False   False
# 2234-XADUH       False           False    False       False   False
# 4801-JZAZL       False           False    False       False   False
# 8361-LTMKD       False           False    False       False   False
# 3186-AJIEK       False           False    False       False   False
#
#              Phone Service  Multiple Lines  Internet Service  Online Security  \
# Customer ID
# 7590-VHVEG           False           False             False            False
# 5575-GNVDE           False           False             False            False
# 3668-QPYBK           False           False             False            False
# 7795-CFOCW           False           False             False            False
# 9237-HQITU           False           False             False            False
# ...                    ...             ...               ...              ...
# 6840-RESVB           False           False             False            False
# 2234-XADUH           False           False             False            False
# 4801-JZAZL           False           False             False            False
# 8361-LTMKD           False           False             False            False
# 3186-AJIEK           False           False             False            False
#
#              Online Backup  Device Protection  Tech Support  Streaming TV  \
# Customer ID
# 7590-VHVEG           False              False         False         False
# 5575-GNVDE           False              False         False         False
# 3668-QPYBK           False              False         False         False
# 7795-CFOCW           False              False         False         False
# 9237-HQITU           False              False         False         False
# ...                    ...                ...           ...           ...
# 6840-RESVB           False              False         False         False
# 2234-XADUH           False              False         False         False
# 4801-JZAZL           False              False         False         False
# 8361-LTMKD           False              False         False         False
# 3186-AJIEK           False              False         False         False
#
#              Streaming Movies  Contract  Paperless Billing  Payment Method  \
# Customer ID
# 7590-VHVEG              False     False              False           False
# 5575-GNVDE              False     False              False           False
# 3668-QPYBK              False     False              False           False
# 7795-CFOCW              False     False              False           False
# 9237-HQITU              False     False              False           False
# ...                       ...       ...                ...             ...
# 6840-RESVB              False     False              False           False
# 2234-XADUH              False     False              False           False
# 4801-JZAZL              False     False              False           False
# 8361-LTMKD              False     False              False           False
# 3186-AJIEK              False     False              False           False
#
#              Monthly Charges  Total Charges  Churn
# Customer ID
# 7590-VHVEG             False          False  False
# 5575-GNVDE             False          False  False
# 3668-QPYBK             False          False  False
# 7795-CFOCW             False          False  False
# 9237-HQITU             False          False  False
# ...                      ...            ...    ...
# 6840-RESVB             False          False  False
# 2234-XADUH             False          False  False
# 4801-JZAZL             False          False  False
# 8361-LTMKD             False          False  False
# 3186-AJIEK             False          False  False
#
# [7043 rows x 20 columns]

# %%
df.isnull().sum()
# Out:
# LoyaltyID            0
# Senior Citizen       0
# Partner              0
# Dependents           0
# Tenure               0
# Phone Service        0
# Multiple Lines       0
# Internet Service     0
# Online Security      0
# Online Backup        0
# Device Protection    0
# Tech Support         0
# Streaming TV         0
# Streaming Movies     0
# Contract             0
# Paperless Billing    0
# Payment Method       0
# Monthly Charges      0
# Total Charges        0
# Churn                0
# dtype: int64

# %% [markdown]
# ## Dropping Null Values
#
# Removing null values is very straightforward. However, it is not always the best approach to deal with null values. And here comes the dilemma of dropping vs imputation, replacing nulls with some reasonable non-null values.
#
# In general, dropping should only be performed when we have a small amount of null data because we cannot just drop single values from the DataFrame — dropping means removing full rows or full columns.
#
# dropna() allows us to very easily drop rows or columns. Whether we should go by rows or columns depends on the dataset at hand; there is no rule here.
#
# By default, this method will drop all rows in which any null value is present and return a new DataFrame without altering the original one. If we want to modify our original DataFrame inplace instead, we can specify inplace=True.
#
# Alternatively, we can drop all columns containing any null values by specifying axis=1.

# %%
# Drop all rows with any missing data
df.dropna()

# Drop all the columns containing any missing data
df.dropna(axis=1)
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 7590-VHVEG      318537             No     Yes         No       1
# 5575-GNVDE      152148             No      No         No      34
# 3668-QPYBK      326527             No      No         No       2
# 7795-CFOCW      845894             No      No         No      45
# 9237-HQITU      503388             No      No         No       2
# ...                ...            ...     ...        ...     ...
# 6840-RESVB      810338             No     Yes        Yes      24
# 2234-XADUH      230811             No     Yes        Yes      72
# 4801-JZAZL      155157             No     Yes        Yes      11
# 8361-LTMKD      731782            Yes     Yes         No       4
# 3186-AJIEK      353947             No      No         No      66
#
#             Phone Service    Multiple Lines Internet Service Online Security  \
# Customer ID
# 7590-VHVEG             No  No phone service              DSL              No
# 5575-GNVDE            Yes                No              DSL             Yes
# 3668-QPYBK            Yes                No              DSL             Yes
# 7795-CFOCW             No  No phone service              DSL             Yes
# 9237-HQITU            Yes                No      Fiber optic              No
# ...                   ...               ...              ...             ...
# 6840-RESVB            Yes               Yes              DSL             Yes
# 2234-XADUH            Yes               Yes      Fiber optic              No
# 4801-JZAZL             No  No phone service              DSL             Yes
# 8361-LTMKD            Yes               Yes      Fiber optic              No
# 3186-AJIEK            Yes                No      Fiber optic             Yes
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 7590-VHVEG            Yes                No           No           No
# 5575-GNVDE             No               Yes           No           No
# 3668-QPYBK            Yes                No           No           No
# 7795-CFOCW             No               Yes          Yes           No
# 9237-HQITU             No                No           No           No
# ...                   ...               ...          ...          ...
# 6840-RESVB             No               Yes          Yes          Yes
# 2234-XADUH            Yes               Yes           No          Yes
# 4801-JZAZL             No                No           No           No
# 8361-LTMKD             No                No           No           No
# 3186-AJIEK             No               Yes          Yes          Yes
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 7590-VHVEG                No  Month-to-month               Yes
# 5575-GNVDE                No        One year                No
# 3668-QPYBK                No  Month-to-month               Yes
# 7795-CFOCW                No        One year                No
# 9237-HQITU                No  Month-to-month               Yes
# ...                      ...             ...               ...
# 6840-RESVB               Yes        One year               Yes
# 2234-XADUH               Yes        One year               Yes
# 4801-JZAZL                No  Month-to-month               Yes
# 8361-LTMKD                No  Month-to-month               Yes
# 3186-AJIEK               Yes        Two year               Yes
#
#                         Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 7590-VHVEG            Electronic check            29.85         29.85    No
# 5575-GNVDE                Mailed check            56.95        1889.5    No
# 3668-QPYBK                Mailed check            53.85        108.15   Yes
# 7795-CFOCW   Bank transfer (automatic)            42.30       1840.75    No
# 9237-HQITU            Electronic check            70.70        151.65   Yes
# ...                                ...              ...           ...   ...
# 6840-RESVB                Mailed check            84.80        1990.5    No
# 2234-XADUH     Credit card (automatic)           103.20        7362.9    No
# 4801-JZAZL            Electronic check            29.60        346.45    No
# 8361-LTMKD                Mailed check            74.40         306.6   Yes
# 3186-AJIEK   Bank transfer (automatic)           105.65        6844.5    No
#
# [7043 rows x 20 columns]

# %% [markdown]
# # Imputation(Filling Null Values)

# %% [markdown]
# As we have just seen, dropping rows or columns with missing data can result in a losing a significant amount of interesting data. So often, rather than dropping data, we replace missing values with a valid value. This new value can be a single number, like zero, or it can be some sort of imputation or interpolation from the good values, like the mean or the median value of that column. For doing this, Pandas provides us with the very handy fillna() method for doing this.

# %%
# Getting the mean value for the column:
Tenure = df['Tenure']
ten_mean = Tenure.mean()

print("Mean Revenue:", ten_mean)
# Out:
# Mean Revenue: 32.37114865824223

# %%
# Let's fill the nulls with the mean value:
Tenure.fillna(ten_mean, inplace=True)

# Let's get the updated status of our DataFrame:
df.isnull().sum()

# %%
df.head()
# Out:
#    LoyaltyID Customer ID Senior Citizen Partner Children  Tenure  \
# 0     318537  7590-VHVEG             No     Yes       No       1
# 1     152148  5575-GNVDE             No      No       No      34
# 2     326527  3668-QPYBK             No      No       No       2
# 3     845894  7795-CFOCW             No      No       No      45
# 4     503388  9237-HQITU             No      No       No       2
#
#   Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 0            No  No phone service              DSL              No  ...
# 1           Yes                No              DSL             Yes  ...
# 2           Yes                No              DSL             Yes  ...
# 3            No  No phone service              DSL             Yes  ...
# 4           Yes                No      Fiber optic              No  ...
#
#   IT Support Streaming TV Streaming Movies        Contract Paperless Billing  \
# 0         No           No               No  Month-to-month               Yes
# 1         No           No               No        One year                No
# 2         No           No               No  Month-to-month               Yes
# 3        Yes           No               No        One year                No
# 4         No           No               No  Month-to-month               Yes
#
#               Payment Method Monthly Charges Total Charges  Churn           IS
# 0           Electronic check           29.85         29.85     No          DSL
# 1               Mailed check           56.95       1889.50     No          DSL
# 2               Mailed check           53.85        108.15    Yes          DSL
# 3  Bank transfer (automatic)           42.30       1840.75     No          DSL
# 4           Electronic check           70.70        151.65    Yes  Fiber optic
#
# [5 rows x 22 columns]

# %%
## Questions

#Return a dataframe with Fibre Optic customers that churned.

#How many senior citizens use bank transfer as their Payment Method?

#Return a dataframe with Customers who either streamTV or streamMovies

#How many customers dont have internet Service?

#Return a dataframe with Customers that use Electronic Check or Mailed Check or Credit card as a mode of payment

#Who is our highest paying customer in terms of Total charges?

# %%
df['Internet Service'].value_counts()
# Out:
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: Internet Service, dtype: int64

# %%
filt3=(df['Senior Citizen']=='Yes') & (df['Churn']=='Yes')
df[filt3]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 8779-QRDMV      352579            Yes      No         No       1
# 7495-OOKFY      820164            Yes     Yes         No       8
# 1658-BYGOY      272229            Yes      No         No      18
# 4598-XLKNJ      405965            Yes     Yes         No      25
# 4846-WHAFZ      527414            Yes     Yes         No      37
# ...                ...            ...     ...        ...     ...
# 6583-QGCSI      510342            Yes     Yes         No      50
# 1980-KXVPM      250380            Yes      No         No       3
# 0723-DRCLG      806194            Yes     Yes         No       1
# 6894-LFHLY      137858            Yes      No         No       1
# 8361-LTMKD      731782            Yes     Yes         No       4
#
#             Phone Service    Multiple Lines Internet Service Online Security  \
# Customer ID
# 8779-QRDMV             No  No phone service              DSL              No
# 7495-OOKFY            Yes               Yes      Fiber optic              No
# 1658-BYGOY            Yes               Yes      Fiber optic              No
# 4598-XLKNJ            Yes                No      Fiber optic              No
# 4846-WHAFZ            Yes               Yes      Fiber optic              No
# ...                   ...               ...              ...             ...
# 6583-QGCSI            Yes               Yes      Fiber optic              No
# 1980-KXVPM            Yes               Yes      Fiber optic              No
# 0723-DRCLG            Yes               Yes      Fiber optic              No
# 6894-LFHLY            Yes               Yes      Fiber optic              No
# 8361-LTMKD            Yes               Yes      Fiber optic              No
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 8779-QRDMV             No               Yes           No           No
# 7495-OOKFY            Yes                No           No           No
# 1658-BYGOY             No                No           No          Yes
# 4598-XLKNJ            Yes               Yes           No          Yes
# 4846-WHAFZ             No                No           No           No
# ...                   ...               ...          ...          ...
# 6583-QGCSI            Yes                No           No          Yes
# 1980-KXVPM             No                No           No           No
# 0723-DRCLG             No                No           No           No
# 6894-LFHLY             No                No           No           No
# 8361-LTMKD             No                No           No           No
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 8779-QRDMV               Yes  Month-to-month               Yes
# 7495-OOKFY                No  Month-to-month               Yes
# 1658-BYGOY               Yes  Month-to-month               Yes
# 4598-XLKNJ               Yes  Month-to-month               Yes
# 4846-WHAFZ                No  Month-to-month               Yes
# ...                      ...             ...               ...
# 6583-QGCSI                No  Month-to-month               Yes
# 1980-KXVPM                No  Month-to-month               Yes
# 0723-DRCLG                No  Month-to-month               Yes
# 6894-LFHLY                No  Month-to-month               Yes
# 8361-LTMKD                No  Month-to-month               Yes
#
#                       Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 8779-QRDMV          Electronic check            39.65         39.65   Yes
# 7495-OOKFY   Credit card (automatic)            80.65         633.3   Yes
# 1658-BYGOY          Electronic check            95.45       1752.55   Yes
# 4598-XLKNJ          Electronic check            98.50        2514.5   Yes
# 4846-WHAFZ          Electronic check            76.50       2868.15   Yes
# ...                              ...              ...           ...   ...
# 6583-QGCSI          Electronic check            88.05       4367.35   Yes
# 1980-KXVPM   Credit card (automatic)            75.05        256.25   Yes
# 0723-DRCLG          Electronic check            74.45         74.45   Yes
# 6894-LFHLY          Electronic check            75.75         75.75   Yes
# 8361-LTMKD              Mailed check            74.40         306.6   Yes
#
# [476 rows x 20 columns]

# %%
filt7=(df['Contract']=='Month-to-month') & (df['Monthly Charges']>60)
df[filt7]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 9237-HQITU      503388             No      No         No       2
# 9305-CDSKC      160192             No      No         No       8
# 1452-KIOVK      680623             No      No        Yes      22
# 7892-POOKP      582674             No     Yes         No      28
# 0280-XJGEX      933642             No      No         No      49
# ...                ...            ...     ...        ...     ...
# 6894-LFHLY      137858            Yes      No         No       1
# 9767-FFLEM      477869             No      No         No      38
# 0639-TSIQW      175841             No      No         No      67
# 8456-QDAVC      956970             No      No         No      19
# 8361-LTMKD      731782            Yes     Yes         No       4
#
#             Phone Service Multiple Lines Internet Service Online Security  \
# Customer ID
# 9237-HQITU            Yes             No      Fiber optic              No
# 9305-CDSKC            Yes            Yes      Fiber optic              No
# 1452-KIOVK            Yes            Yes      Fiber optic              No
# 7892-POOKP            Yes            Yes      Fiber optic              No
# 0280-XJGEX            Yes            Yes      Fiber optic              No
# ...                   ...            ...              ...             ...
# 6894-LFHLY            Yes            Yes      Fiber optic              No
# 9767-FFLEM            Yes             No      Fiber optic              No
# 0639-TSIQW            Yes            Yes      Fiber optic             Yes
# 8456-QDAVC            Yes             No      Fiber optic              No
# 8361-LTMKD            Yes            Yes      Fiber optic              No
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 9237-HQITU             No                No           No           No
# 9305-CDSKC             No               Yes           No          Yes
# 1452-KIOVK            Yes                No           No          Yes
# 7892-POOKP             No               Yes          Yes          Yes
# 0280-XJGEX            Yes               Yes           No          Yes
# ...                   ...               ...          ...          ...
# 6894-LFHLY             No                No           No           No
# 9767-FFLEM             No                No           No           No
# 0639-TSIQW            Yes               Yes           No          Yes
# 8456-QDAVC             No                No           No          Yes
# 8361-LTMKD             No                No           No           No
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 9237-HQITU                No  Month-to-month               Yes
# 9305-CDSKC               Yes  Month-to-month               Yes
# 1452-KIOVK                No  Month-to-month               Yes
# 7892-POOKP               Yes  Month-to-month               Yes
# 0280-XJGEX               Yes  Month-to-month               Yes
# ...                      ...             ...               ...
# 6894-LFHLY                No  Month-to-month               Yes
# 9767-FFLEM                No  Month-to-month               Yes
# 0639-TSIQW                No  Month-to-month               Yes
# 8456-QDAVC                No  Month-to-month               Yes
# 8361-LTMKD                No  Month-to-month               Yes
#
#                         Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 9237-HQITU            Electronic check            70.70        151.65   Yes
# 9305-CDSKC            Electronic check            99.65         820.5   Yes
# 1452-KIOVK     Credit card (automatic)            89.10        1949.4    No
# 7892-POOKP            Electronic check           104.80       3046.05   Yes
# 0280-XJGEX   Bank transfer (automatic)           103.70        5036.3   Yes
# ...                                ...              ...           ...   ...
# 6894-LFHLY            Electronic check            75.75         75.75   Yes
# 9767-FFLEM     Credit card (automatic)            69.50       2625.25    No
# 0639-TSIQW     Credit card (automatic)           102.95       6886.25   Yes
# 8456-QDAVC   Bank transfer (automatic)            78.70        1495.1    No
# 8361-LTMKD                Mailed check            74.40         306.6   Yes
#
# [2382 rows x 20 columns]

# %%
filt6=(df['Internet Service']=='Fiber optic') & (df['Churn']=='Yes')
df[filt6]
# Out:
#              LoyaltyID Senior Citizen Partner Dependents  Tenure  \
# Customer ID
# 9237-HQITU      503388             No      No         No       2
# 9305-CDSKC      160192             No      No         No       8
# 7892-POOKP      582674             No     Yes         No      28
# 0280-XJGEX      933642             No      No         No      49
# 6467-CHFZW      100681             No     Yes        Yes      47
# ...                ...            ...     ...        ...     ...
# 0723-DRCLG      806194            Yes     Yes         No       1
# 1122-JWTJW      961184             No     Yes        Yes       1
# 6894-LFHLY      137858            Yes      No         No       1
# 0639-TSIQW      175841             No      No         No      67
# 8361-LTMKD      731782            Yes     Yes         No       4
#
#             Phone Service Multiple Lines Internet Service Online Security  \
# Customer ID
# 9237-HQITU            Yes             No      Fiber optic              No
# 9305-CDSKC            Yes            Yes      Fiber optic              No
# 7892-POOKP            Yes            Yes      Fiber optic              No
# 0280-XJGEX            Yes            Yes      Fiber optic              No
# 6467-CHFZW            Yes            Yes      Fiber optic              No
# ...                   ...            ...              ...             ...
# 0723-DRCLG            Yes            Yes      Fiber optic              No
# 1122-JWTJW            Yes             No      Fiber optic              No
# 6894-LFHLY            Yes            Yes      Fiber optic              No
# 0639-TSIQW            Yes            Yes      Fiber optic             Yes
# 8361-LTMKD            Yes            Yes      Fiber optic              No
#
#             Online Backup Device Protection Tech Support Streaming TV  \
# Customer ID
# 9237-HQITU             No                No           No           No
# 9305-CDSKC             No               Yes           No          Yes
# 7892-POOKP             No               Yes          Yes          Yes
# 0280-XJGEX            Yes               Yes           No          Yes
# 6467-CHFZW            Yes                No           No          Yes
# ...                   ...               ...          ...          ...
# 0723-DRCLG             No                No           No           No
# 1122-JWTJW             No                No           No           No
# 6894-LFHLY             No                No           No           No
# 0639-TSIQW            Yes               Yes           No          Yes
# 8361-LTMKD             No                No           No           No
#
#             Streaming Movies        Contract Paperless Billing  \
# Customer ID
# 9237-HQITU                No  Month-to-month               Yes
# 9305-CDSKC               Yes  Month-to-month               Yes
# 7892-POOKP               Yes  Month-to-month               Yes
# 0280-XJGEX               Yes  Month-to-month               Yes
# 6467-CHFZW               Yes  Month-to-month               Yes
# ...                      ...             ...               ...
# 0723-DRCLG                No  Month-to-month               Yes
# 1122-JWTJW                No  Month-to-month               Yes
# 6894-LFHLY                No  Month-to-month               Yes
# 0639-TSIQW                No  Month-to-month               Yes
# 8361-LTMKD                No  Month-to-month               Yes
#
#                         Payment Method  Monthly Charges Total Charges Churn
# Customer ID
# 9237-HQITU            Electronic check            70.70        151.65   Yes
# 9305-CDSKC            Electronic check            99.65         820.5   Yes
# 7892-POOKP            Electronic check           104.80       3046.05   Yes
# 0280-XJGEX   Bank transfer (automatic)           103.70        5036.3   Yes
# 6467-CHFZW            Electronic check            99.35       4749.15   Yes
# ...                                ...              ...           ...   ...
# 0723-DRCLG            Electronic check            74.45         74.45   Yes
# 1122-JWTJW                Mailed check            70.65         70.65   Yes
# 6894-LFHLY            Electronic check            75.75         75.75   Yes
# 0639-TSIQW     Credit card (automatic)           102.95       6886.25   Yes
# 8361-LTMKD                Mailed check            74.40         306.6   Yes
#
# [1297 rows x 20 columns]

# %%
filt7=(df['Streaming TV']=='Yes') & (df['Streaming Movies']=='Yes')
df[filt7]
# Out:
#       LoyaltyID Customer ID Senior Citizen Partner Children  Tenure  \
# 5        160192  9305-CDSKC             No      No       No       8
# 8        582674  7892-POOKP             No     Yes       No      28
# 12       158680  8091-TTVAX             No     Yes       No      58
# 13       933642  0280-XJGEX             No      No       No      49
# 14       529260  5129-JLPIS             No      No       No      25
# ...         ...         ...            ...     ...      ...     ...
# 7029     695438  2235-DWLJU            Yes      No       No       6
# 7036     210184  7750-EYXWZ             No      No       No      12
# 7038     810338  6840-RESVB             No     Yes      Yes      24
# 7039     230811  2234-XADUH             No     Yes      Yes      72
# 7042     353947  3186-AJIEK             No      No       No      66
#
#      Phone Service    Multiple Lines Internet Service Online Security  ...  \
# 5              Yes               Yes      Fiber optic              No  ...
# 8              Yes               Yes      Fiber optic              No  ...
# 12             Yes               Yes      Fiber optic              No  ...
# 13             Yes               Yes      Fiber optic              No  ...
# 14             Yes                No      Fiber optic             Yes  ...
# ...            ...               ...              ...             ...  ...
# 7029            No  No phone service              DSL              No  ...
# 7036            No  No phone service              DSL              No  ...
# 7038           Yes               Yes              DSL             Yes  ...
# 7039           Yes               Yes      Fiber optic              No  ...
# 7042           Yes                No      Fiber optic             Yes  ...
#
#      IT Support Streaming TV Streaming Movies        Contract  \
# 5            No          Yes              Yes  Month-to-month
# 8           Yes          Yes              Yes  Month-to-month
# 12           No          Yes              Yes        One year
# 13           No          Yes              Yes  Month-to-month
# 14          Yes          Yes              Yes  Month-to-month
# ...         ...          ...              ...             ...
# 7029         No          Yes              Yes  Month-to-month
# 7036        Yes          Yes              Yes        One year
# 7038        Yes          Yes              Yes        One year
# 7039         No          Yes              Yes        One year
# 7042        Yes          Yes              Yes        Two year
#
#      Paperless Billing             Payment Method Monthly Charges  \
# 5                  Yes           Electronic check           99.65
# 8                  Yes           Electronic check          104.80
# 12                  No    Credit card (automatic)          100.35
# 13                 Yes  Bank transfer (automatic)          103.70
# 14                 Yes           Electronic check          105.50
# ...                ...                        ...             ...
# 7029               Yes           Electronic check           44.40
# 7036                No           Electronic check           60.65
# 7038               Yes               Mailed check           84.80
# 7039               Yes    Credit card (automatic)          103.20
# 7042               Yes  Bank transfer (automatic)          105.65
#
#      Total Charges  Churn           IS
# 5           820.50    Yes  Fiber optic
# 8          3046.05    Yes  Fiber optic
# 12         5681.10     No  Fiber optic
# 13         5036.30    Yes  Fiber optic
# 14         2686.05     No  Fiber optic
# ...            ...    ...          ...
# 7029        263.05     No          DSL
# 7036        743.30     No          DSL
# 7038       1990.50     No          DSL
# 7039       7362.90     No  Fiber optic
# 7042       6844.50     No  Fiber optic
#
# [1940 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['LoyaltyID', 'Customer ID', 'Senior Citizen', 'Partner', 'Children',
#        'Tenure', 'Phone Service', 'Multiple Lines', 'Internet Service',
#        'Online Security', 'Online Backup', 'Device Protection', 'IT Support',
#        'Streaming TV', 'Streaming Movies', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charges', 'Total Charges', 'Churn', 'IS'],
#       dtype='object')

# %% [markdown]
# <B>##########################################  The END, Thank You  ####################################### <B>
