# %% [markdown]
# # INNER JOIN
#
# The INNER JOIN keyword selects records that have matching values in both tables.

# %% [raw]
# Syntax
#
# SELECT column_name(s)
# FROM table1
# INNER JOIN table2
# ON table1.column_name = table2.column_name;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Example
# Using Database World,use the cities and countries tables to build your first inner join.
# Guide:
# - Identify the relevant column names to join ON by inspecting the cities and countries
# - Perform an inner join with the cities table on the left and the countries table on the right;
# - Keep only the name of the city, the name of the country, and the region the country is locate in using the SELECT statement.
# - Alias the name of the city AS city and the name of the country AS country

# %% [raw]
# SELECT cities.name AS city, countries.name AS country, region
# FROM cities
# INNER JOIN countries
# ON cities.country_code = countries.code;

# %% [markdown]
# ## Question 1
#
# - Write an SQL Query that joins tables country and economies where there are matching values on both tables.
# - Use an alieas name for countries as c and economies as e
# - Keep only the name of the code from the countries table (alias it as country_code), name, year, and inflation_rate.

# %% [markdown]
# Answer

# %% [markdown]
# ---

# %% [markdown]
# # LEFT JOIN
#
# The LEFT JOIN keyword returns all records from the left table (table1), and the matching records from the right table (table2). The result is 0 records from the right side, if there is no match.
#
# In some databases LEFT JOIN is called LEFT OUTER JOIN.

# %% [raw]
# Syntax
#
# SELECT column_name(s)
# FROM table1
# LEFT JOIN table2
# ON table1.column_name = table2.column_name;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ---

# %% [markdown]
# # RIGHT JOIN
#
# The RIGHT JOIN keyword returns all records from the right table (table2), and the matching records from the left table (table1). The result is 0 records from the left side, if there is no match.
#
# In some databases RIGHT JOIN is called RIGHT OUTER JOIN.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 2
#
#
# - Write an SQL Query that joins tables country and cities
# - All the cities will need to be there
# - Use an alias name for countries as c1 and city as c2
# - Keep only the name of the city from cities table (alias it as city), name of country(alias it as country), region, ans city_proper_pop

# %% [markdown]
# ## Full JOIN
#
# The FULL OUTER JOIN keyword returns all records when there is a match in left (table1) or right (table2) table records.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Syntax
#
# SELECT column_name(s)
# FROM table1
# FULL OUTER JOIN table2
# ON table1.column_name = table2.column_name
# WHERE condition;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 3
#
#
# - Perform a full join with countries (left) and currencies (right).
# - Filter for the North America region or NULL country names.
# - Order by region
