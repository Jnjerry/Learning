# %% [markdown]
# Visualizations allow us to gain insights into our data by making things easier to understand. When we place data into a visual context patterns, trends, and correlations that might have otherwise gone undetected rise to the surface.

# %% [markdown]
# In the middle stages of a project, we can use visualizations to gain more insights and generalize model results.
#
# Towards the end of a project, it’s very important to be able to present our results in a clear, concise, and compelling manner so that our audience (which is often made up of non-technical people) can understand the results.

# %% [markdown]
# ## Data Visualization Libraries and Tools
#
# 1. Matplotlib - Matplotlib is a Python library that helps with data visualization. It’s a 2D plotting library which produces different types of figures. It can be used with Python scripts, Jupyter notebooks, application servers, etc
# 2. Seaborn - Seaborn was created on top of Matplotlib. It’s a wrapper around Matplotlib that is easy to use. Its color palettes are better, and it produces industry-standard plots. A few commonly used plots, which require large lines of code in Matplotlib can easily be generated with one line in Seaborn.
# 3. Bokeh - Bokeh is an interactive graphical library. It was designed to target the modern web browser. It provides high-end integrity with the capability of handling large and streaming datasets, and has support in different languages
# 4. Plotly - An interactive library. Provides good quality plots like dendrograms, 3D plotting, etc.
# 5. Geoplotlib - creates maps and plots geographical data.
# 6. PowerBI
# 7. Tableau

# %% [markdown]
# ---

# %%
#INSTALLATION

# %%
#!pip install matplotlib

# %%
#!pip install seaborn

# %%
## import libraries
# %matplotlib inline
#this is a predefined magic function in Ipython -  makes your plot outputs appear and be stored within the notebook.
# %matplotlib notebook

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #  Matplotlib

# %% [markdown]
# ## Introduction to Matplotlib Concepts.
# ### We will define the following Matplotlib Concepts
#
# 1. Figure
# 2. Axes
# 3. Axis
# 4. Artist

# %% [markdown]
# ## Figure
# - This is the top level container for all the plotted elements.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Axes
#  - The axes are marked by the blue box. They are where the data will appear.

# %% [markdown]
# ## Axis
# - The x-axis and the y-axis, both circled in green, are number-line-like objects. They set the graph limits and generate the ticks (the marks on the axis) and the tick labels (the strings labeling the ticks).

# %% [markdown]
# ## Artist
#  - Collection of objects in your figure
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Drawing a Figure
# - There are three ways of drawing a figure
#
# 1. Using the Pyplot module
# 2. Using the axes object
# 3. Using the figure object

# %% [markdown]
# ### 1. Using the Pyplot module

# %%
import matplotlib.pyplot as plt

# %%
x=[20,22,24,25,26]
y=[30,32,34,36,38]


plt.plot(x,y)

# %% [markdown]
# ### 2. Using the axes method
#
# 1. assign a variable name to the subplot method.(subplot)
# 2. Use the variable name to plot any graph of your choice

# %%
x=[10, 12, 14, 16]
y=[20, 29, 600, 1000]

#give it a variable name
ax1=plt.subplot()


ax1.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### 3. From the Figure module
# Use the substeps below
# 1. Create a canvas (figure) explicitly.
# 2. Create a plot object by using add_subplot from the figure object.
# 3. Finally, plot the chart by calling plot

# %%
### 3. From the Figure module
x=[10, 12, 14, 16]
y=[20, 22, 30, 70]

fig=figure()
ax1=fig.add_subplot()
ax1.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Going back to a figure let's see the different manipulation we can do on the different elements

# %% [markdown]
# ## Ticks
# - Ticks are the values used to show specific points on the coordinate axis. It can be a number or a string. Whenever we plot a graph, the axes adjust and take the default ticks. Matplotlib’s default ticks are generally sufficient in common situations but are in no way optimal for every plot.

# %% [markdown]
# ### The following are some properties that we can manipulate by setting parameters:
#
# which: Sets the x/y major/minor ticks. The default value is major.
#
# color: Sets the tick color.
#
# labelrotation: Rotates the tick label.
#
# width: Sets the tick width in points.
#
# length: Sets the tick length in points.
#
# direction: Sets the direction of the ticks, either towards the axis or away from it. The default value is out.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.tick_params.html

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %%
import matplotlib.pyplot as plt

# %%
### Changing parameters
pop1=[10, 12, 14, 16]
pop2=[20, 22, 30, 70]



#plt.plot(class7scores)
plt.plot(pop1)
plt.plot(pop2)
plt.tick_params(axis='both',color="blue", length=10, labelsize=25)
plt.legend(["population1","population2"],loc="upper left",labelcolor="purple")
plt.title('Population sizes')
plt.xlabel("range")
plt.ylabel("population size(million)")






## modify the x axis using axis='x'
## modify both the x and y axis using axis='both'
# Out:
# Text(0, 0.5, 'population size(million)')

# %% [markdown]
# ## Adding a Legend
# - A legend provides a description for an element in the figure. A legend helps the user understand a figure when the figure contains many elements. For example, if there are two curves on a graph, then the legend can help the user distinguish between the curves.
#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.legend.html

# %%
x=[10, 12, 14, 16]
y=[20, 22, 30, 70]


ax=plt.subplot()
ax.plot(x,y)
ax.legend(["x"])

plt.show()

# %%
x=[10, 12, 14, 16]
y=[20, 22, 30, 70]


plt.plot(x,y)
plt.legend(["blue"], loc ="lower right")

# %%
x=[10, 12, 14, 16]
y=[20, 22, 30, 70]


plt.plot(x)
plt.plot(y)
plt.legend(["blue","red"], loc ="upper right")

# add the title
# change fontsize

# %%
## Labeling the x and y axis
x=[10, 12, 14, 16]
y=[20, 22, 30, 70]


plt.plot(x)
plt.plot(y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(["blue","red"], loc ="upper right")

# %%
## Add a title
## Labeling the x and y axis
x=[10, 12, 14, 16]
y=[20, 22, 30, 70]


plt.plot(x)
plt.plot(y)
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.title("myFigure")
plt.legend(["blue","red"], loc ="upper right")

# %% [markdown]
# # Put it together

# %% [markdown]
# ## Line Plot with Stocks Data

# %%
#!pip install yfinance

#!pip install yahoofinancials

# %%
## import the files
import yfinance as yf

#from yahoofinancials import YahooFinancials

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## We will download the stock price for Microsoft between the beginning of 2020 and mid 2021

# %%
df = yf.download('MSFT', start='2020-01-01', end='2021-06-12' )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df2 = yf.download('TWTR', start='2021-01-01', end='2021-12-30' )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df2=df2.reset_index()

# %%
figure(figsize=(20, 10), dpi=80)
plt.plot(df2["Date"],df2[['High',"Low"]])

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-12-31  156.770004  157.770004  156.449997  157.699997  154.749741
# 2020-01-02  158.779999  160.729996  158.330002  160.619995  157.615128
# 2020-01-03  158.320007  159.949997  158.059998  158.619995  155.652527
# 2020-01-06  157.080002  159.100006  156.509995  159.029999  156.054871
# 2020-01-07  159.320007  159.669998  157.320007  157.580002  154.631989
#
#               Volume
# Date
# 2019-12-31  18369400
# 2020-01-02  22622100
# 2020-01-03  21116200
# 2020-01-06  20813700
# 2020-01-07  21634100

# %%
df.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 360 2021-06-07  249.979996  254.089996  249.809998  253.809998  252.862411
# 361 2021-06-08  255.160004  256.010010  252.509995  252.570007  251.627060
# 362 2021-06-09  253.809998  255.529999  253.210007  253.589996  252.643234
# 363 2021-06-10  254.289993  257.459991  253.669998  257.239990  256.279602
# 364 2021-06-11  257.989990  258.489990  256.609985  257.890015  256.927216
#
#        Volume
# 360  23079200
# 361  22455000
# 362  17937600
# 363  24563600
# 364  18999700

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 365 entries, 2019-12-31 to 2021-06-11
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       365 non-null    float64
#  1   High       365 non-null    float64
#  2   Low        365 non-null    float64
#  3   Close      365 non-null    float64
#  4   Adj Close  365 non-null    float64
#  5   Volume     365 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 20.0 KB

# %%
df.shape
# Out:
# (365, 6)

# %%
# Reseting the index
df = df.reset_index()

# %%
# get the datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       365 non-null    datetime64[ns]
#  1   Open       365 non-null    float64
#  2   High       365 non-null    float64
#  3   Low        365 non-null    float64
#  4   Close      365 non-null    float64
#  5   Adj Close  365 non-null    float64
#  6   Volume     365 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 20.1 KB

# %% [markdown]
# ---

# %% [markdown]
# Definition
#
# Open: The price of the stock when the market opens in the morning
#
# Close: The price of the stock when the market closed in the evening
#
# High: Highest price the stock reached during that day
#
# Low: Lowest price the stock is traded on that day
#
# Volume: The total amount of stocks traded on that day

# %% [markdown]
# ## Using Microsoft's perform the following.
#
# 1. Use Matplotlib to plot stock prices against Date on an Yearly Basis
# 2. Download Googles stock for the same period and draw two axes to compare their traded volume
#
# #### Ensure you have included the following on your Figures
# - Title
# - Labelling the x and y axis
# - Legend

# %%
plt.plot(df['Date'],df[['High']])

# %%
plt.plot(df["Date"],df[['High',"Low","Close"]])

# %%
from matplotlib.pyplot import figure

figure(figsize=(15,10),dpi=80)

plt.plot(df['Date'],df[["High"]])

# %%
## the figure is too small so let's adjust the size
from matplotlib.pyplot import figure
figure(figsize=(20, 10), dpi=80)
plt.plot(df["Date"],df[['High',"Low"]])
plt.title("MSFT Stock Prices 2019- mid 2021")
plt.legend(["High","Low"],loc="upper left")
plt.xlabel("Date")
plt.ylabel("Stock Prices")
# Out:
# Text(0, 0.5, 'Stock Prices')

# %%
## Label the x axis and y axis,
# Add the title
# Adjust the ticks
# Create a legend


figure(figsize=(20,10),dpi=80)
plt.title("Stock Prices for MSFT(2019-2020)")
plt.xlabel("Date")
plt.ylabel("Opening and Closing Stock")
plt.plot(df["Date"],df[["Close","Open"]])
plt.legend(["Close","Open"])

# %%
## Comparing MSFT vs GOOGLE
df2 = yf.download('GOOGL', start='2019-01-01', end='2021-06-12', )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df2.head()
# Out:
#    index       Date         Open         High          Low        Close  \
# 0      0 2018-12-31  1057.829956  1062.989990  1033.040039  1044.959961
# 1      1 2019-01-02  1027.199951  1060.790039  1025.280029  1054.680054
# 2      2 2019-01-03  1050.670044  1066.260010  1022.369995  1025.469971
# 3      3 2019-01-04  1042.560059  1080.000000  1036.859985  1078.069946
# 4      4 2019-01-07  1080.969971  1082.699951  1062.640015  1075.920044
#
#      Adj Close   Volume
# 0  1044.959961  1655500
# 1  1054.680054  1593400
# 2  1025.469971  2098000
# 3  1078.069946  2301100
# 4  1075.920044  2372300

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 617 entries, 0 to 616
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   index      617 non-null    int64
#  1   Date       617 non-null    datetime64[ns]
#  2   Open       617 non-null    float64
#  3   High       617 non-null    float64
#  4   Low        617 non-null    float64
#  5   Close      617 non-null    float64
#  6   Adj Close  617 non-null    float64
#  7   Volume     617 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(2)
# memory usage: 38.7 KB

# %%
df2=df2.reset_index()

# %% [markdown]
# REFERENCE
# https://matplotlib.org/stable/api/axes_api.html

# %%
fig=figure(figsize=(20,10))

plot1=fig.add_axes([0,0,1,1])
plot2=fig.add_axes([0.05, 0.65, 0.5, 0.3])


plot1.plot(df['Date'],df['High'], color="purple")
plot1.set_title("MSFT vs Google")
plot1.set_xlabel("Date")
plot1.set_ylabel("Price")
plot1.legend(["Microsoft"])


plot2.plot(df2['Date'],df2['High'],color="red")
plot2.set_title("Google")
plot2.set_xlabel("Date")
plot2.set_ylabel("Price")
plot2.legend(["Google"])
#try plot google on plot2

# %%
fig = figure(figsize=(20,10))

ax1 = fig.add_axes([0, 0, 1, 1])
ax2 = fig.add_axes([0.05, 0.65, 0.5, 0.3])




ax1.plot(df["Date"],df["Adj Close"], color="orange")
ax1.set_title("MSFT",fontsize=30)
ax1.set_xlabel("Date")
ax1.set_ylabel("Adj Close")
ax1.legend(["Adj Close(MSFT)"])


ax2.plot(df2["Date"],df2["Adj Close"], color="red")
ax2.set_title("GOOGLE",fontsize=30)
ax2.set_xlabel("Date")
ax2.set_ylabel("Adj Close")
ax2.legend(['Adj Close(Google)'])
